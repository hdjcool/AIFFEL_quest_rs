# %% [markdown]
# ### 학습 목표
# ---
# - 확률의 개념과 기본 법칙을 이해합니다.
# - 조건부 확률과 독립의 의미를 이해합니다.
# - 대표적인 확률 분포인 이항 분포와 정규 분포에 대해 이해합니다.
#
# ### 목차
# ---
# - 확률
#     - 시행과 표본공간
#     - 사건
#     - 확률
#     - 집합 이론 기초
#     - 확률의 성질들
#
# - 조건부확률과 독립
#     - 조건부확률
#     - 확률의 곱셈정리
#     - 전확률과 베이즈 정리
#     - 독립
#     - 상호 배타적 사건과 독립사건의 차이
#
# - 확률 변수
#     - 확률 변수
#     - 분포 함수
#     - 이산 확률 변수
#     - 연속 확률 변수
#     - 기댓값
#     - 분산
#     - 조건부 기댓값
#
# - 분포
#     - 베르누이 시도와 베르누이 분포
#     - 이항분포
#     - 정규 분포
#     - 이항 분포와 정규 분포의 관계

# %% [markdown]
# ## 1-2. 시행과 표본 공간 & 사건
#
# ### 시행과 표본 공간
# ---
# - 실험(experiments) 은 시도(trial)나 관찰(observation)의 과정입니다.
# - 시행(random experiment) 이란 같은 조건 하에서 여러 번 반복할 수 있는 어떤 실험에서, 결과를 알 수는 없지만, 일어날 가능성이 있는 모든 결과를 사전에 알 수 있는 실험입니다.
#
# 예를 들어서 주사위 던지기를 '시행'이라고 할 수 있을까요?
#
# 1. 만약 바람의 세기, 주사위를 던지는 각도와 속도, 주사위가 닿는 바닥의 기울기 등등 모든 초기 환경을 동일하게 여러 번 던질 수 있다면 같은 조건 하에서 여러 번 반복할 수 있는 실험이라 할 수 있습니다.
# 2. 던졌을 때 어떤 숫자가 나올지 미리 알 수 없으므로 결과를 알 수 없는 실험입니다.
# 3. 하지만 최소한 1,2,3,4,5,6 중에 하나가 반드시 나온다는 것을 미리 알고 있는 실험이므로, 일어날 가능성이 있는 모든 결과를 사전에 알 수 있는 실험입니다.
#
# 따라서 위의 1,2,3을 만족하는 주사위 실험은 '시행'이라고 할 수 있습니다.
#
# 시행에서 일어날 가능성이 있는 모든 결과를 원소로 하는 집합을 표본 공간(sample space) 이라고 합니다. 표본 공간을 집합
# Ω라고 하고 그 원소를
# w
# i
# ​
#  라고 표현해봅시다.
#
# n개의 가능한 결과가 있는 실험을 한다면, 표본 공간은 다음과 같습니다.
#
# Ω={w
# 1
# ​
#  ,w
# 2
# ​
#  ,…,w
# n
# ​
#  }
#
# 따라서 주사위의 표본 공간은 다음과 같이 쓸 수 있습니다.
#
# Ω={1,2,3,4,5,6}
#
#
# 표본 공간을 구성하는 집합의 원소가 이산형 데이터이면 이산(discrete) 표본 공간, 연속형 데이터이면 연속(continuous) 표본 공간이라고 합니다.
#
#
# ### 사건
# ---
# 표본 공간에서 특정한 규칙에 의해 정해진 부분 집합을 사건(event) 이라고 합니다.
#
# 예를 들어 주사위를 1개 던졌을 때, 나올 수 있는 모든 경우는
#
# Ω={1,2,3,4,5,6}
# 중에서 짝수가 나올 경우들의 집합을 생각해볼 수 있습니다. 이때는 다음과 같이 사건의 집합을 구할 수 있습니다.
#
# 짝수가 나올 경우={2,4,6}

# %% [markdown]
# Q. 그럼 "홀수가 나올 경우"들의 집합은 뭘까요?
# {1,3,5}

# %% [markdown]
# ## 1-3. 확률
# ---
#
# 확률을 정의하는 방법은 여러 가지가 있습니다. 공리적(axiomatic) 정의, 상대 도수(relative-frequency) 정의 그리고 고전적(classical) 정의가 있습니다.
#
# #### 공리적 정의 (수학적 정의)
# 표본 공간 Ω 에서 사건 A 가 발생할 확률을 P(A) 라고 표현하며 이는 다음을 만족하는 것으로 정의됩니다.
#
# - 공리 1. 0≤P(A). 확률은 항상 0 보다 크거나 같다.
# - 공리 2. P(Ω)=1. 표본 공간 전체의 확률의 합은 1 이다.
# - 공리 3. 하나의 표본 공간에서 정의된 n개의 서로 배타적인 사건
# A
# 1
# ​
#  ,
# A
# 2
# ​
#  ,
# …,A
# n
# ​
#   에 대해서 다음 식이 성립한다.
#
# ![image.png](attachment:image.png)
#
# 시행의 모든 시도에서 A 또는 B 사건이 발생했을 때 다른 하나의 사건이 발생하지 않을 경우 '사건 A 와 B 가 서로 배타적(mutually exclusive) 이다.' 혹은 '사건 A 와 B 는 서로 배반사건이다.' 라고 합니다.
#
#
# #### 상대 도수 정의 (통계적 정의)
# 시행이 n 번 수행됐을 때 사건 A가
# n
# A
# ​
#   번 발생했다면, 사건 A 의 확률 P(A) 는 다음과 같이 정 의됩니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 비율
# n
# A
# ​
#  /n을 사건 A 의 상대 도수(relative frequency) 라고 부릅니다. 직관적으로, 상대 도수 정의는 많은 실제 문제들에서도 적용될 수 있을 것 같지만 사실 한계가 있습니다. 비용이 너무 비싸 여러번 시행을 못할 때일 수도 있고 limit 값이 존재하지 않는 경우도 있습니다.
#
# #### 고전적 정의
# 고전적 정의에서 사건 A 의 확률  P(A)는 다음과 같이 표현됩니다.
#
# ![image-3.png](attachment:image-3.png)
#
# 이 확률은 선험적(a priori) 으로 실험 없이 결정됩니다. 예를 들면, 동전 던지기 실험을 할 때, 우리는 이미 동전의 모든 가능한 경우
# N이 2인 것을 알고 있으므로 평범한 동전이라는 가정하에 앞면이 나올 확율은 1/2인 것을 알 수있습니다.
#
# 이 글에서 다룰 확률은 '공리적 정의에 따른 확률' 입니다.

# %% [markdown]
# Q. 다음 내용은 본문에서 설명한 확률의 세 가지 정의 중 어떤 것에 해당될까요?
# ① 주사위를 던졌을 때 나올 수 있는 숫자가 총 6가지이므로 숫자 1이 나올 확률은 1/6입니다.
# ② 주사위를 여러 번 던져본 결과 숫자 1이 나온 횟수가 전체 시행 횟수의 1/6에 점점 가까워졌기 때문에, 1이 나올 확률은 1/6 정도일 것입니다.
#
# 1. 고전적 정의
# 2. 상대 도수 정의(통계적 정의

# %% [markdown]
# ## 1-4. 집합 이론 기초
# 집합(set)은 원소들(elements)의 모음입니다. 앞에서 언급된 사건들(events)은 일반적으로 집합입니다. 따라서 집합의 연산들은 사건들에도 같게 적용됩니다. 그럼 예제를 통해 집합에서 쓰이는 여러 표현들을 살펴보겠습니다.
#
# A 가 1 이상 6 이하의 정수들의 집합이라고 하면 다음과 같이 쓸 수 있습니다.
#
# ![image.png](attachment:image.png)
#
# B 를 1 이상 6 이하의 정수들 중 짝수들의 집합이라고 하면 다음과 같이 쓸 수 있습니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 이 때 1 은 집합 A 안의 원소이므로 '1 은 A에 포함된다.'라고 하며 1∈A 로 표현합니다. 이어서
# 1 은 B 의 원소가 아니므로 '1 은 B 에 포함되지 않는다' 라고 하며 1∉B 라고 표현합니다.
#
# B 의 원소들은 모두 A 에 포함됩니다. 이와 같은 경우에 'B 는 A 의 부분집합(subset)'이라고 하며 B⊂A라고 표현합니다.
#
# 모든 가능한 원소를 포함하는 집합을 전체집합(universal set) 이라고 하며 이 글에서는 Ω 라고 표기하겠습니다. 앞서 나온 표본 공간이 전체 집합입니다. 그리고 아무 원소도 포함하지 않는 집합을 공집합(null or empty set) 이라고 하며 ∅ 로 표기합니다.

# %% [markdown]
# ### 집합의 연산들
# #### 같음(equality)
#
# ![image.png](attachment:image.png)
#
# #### 교집합(intersection)
#
# ![image-2.png](attachment:image-2.png)
#
# #### 합집합(union)
#
# ![image-3.png](attachment:image-3.png)
#
# #### 여집합(complementary set)
#
# ![image-4.png](attachment:image-4.png)
#
# #### 차집합(difference)
#
# ![image-5.png](attachment:image-5.png)
#
# #### 서로소 집합(disjoint set)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### 1-5. 집합 실행해보기
#
# 수식으로만 써있으니 너무 지루하셨죠? 재미삼아 한번 직접 코드로 그려볼까요? 부담없이 '이런 패키지도 있구나~'하고 편하게 실행시키시면 됩니다. :)
#
# 우선 matplotlib과 연동된 패키지를 pip을 이용해 설치해볼게요.
# cloud shell을 열어서 다음 명령어를 입력하세요.
#
# ```
# $ pip install matplotlib-venn
# ```
# 이제 실행시켜 볼까요?

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn3, venn3_circles

print('1=1')
# Out:
# 1=1

# %%
# 교집합
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 103            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 77            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(0.8) 

v.get_patch_by_id('10').set_color('w') 
v.get_patch_by_id('01').set_color('w') 
v.get_patch_by_id('11').set_color('yellow') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("white")
plt.gca().set_axis_on()

# %%
# 합집합
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(0.8) 

v.get_patch_by_id('10').set_color('lightgreen') 
v.get_patch_by_id('01').set_color('lightblue') 
v.get_patch_by_id('11').set_color('darkblue') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("white")
plt.gca().set_axis_on()

# %%
# 차집합: A-B
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(0.8) 

v.get_patch_by_id('10').set_color('lightgreen') 
v.get_patch_by_id('01').set_color('white') 
v.get_patch_by_id('11').set_color('white') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("white")
plt.gca().set_axis_on()

# %%
# B의 여집합
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13            # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8            # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B, '11': Num_Set_A_and_B}, set_labels = ('A', 'B')) 
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, Num_Set_A_and_B), linestyle='solid') 
v.get_patch_by_id('10').set_alpha(1.0) 
v.get_patch_by_id('01').set_alpha(1.0) 
v.get_patch_by_id('11').set_alpha(1.0) 

v.get_patch_by_id('10').set_color('skyblue') 
v.get_patch_by_id('01').set_color('white') 
v.get_patch_by_id('11').set_color('white') 

v.get_label_by_id('10').set_text(' ') 
v.get_label_by_id('01').set_text(' ') 
v.get_label_by_id('11').set_text(' ') 

v.get_label_by_id('A').set_text('Set A') 
v.get_label_by_id('B').set_text('Set B') 
plt.gca().set_facecolor("skyblue")
plt.gca().set_axis_on()

# %%
# 서로소 집합
fig = plt.figure()
fig.set_size_inches(10,8)

Num_Set_A = 13             # A 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_B = 8               # B 집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.
Num_Set_A_and_B = 5    # A와 B의 교집합의 원소 개수입니다. 마음대로 바꾸실 수 있어요.

v = venn2(subsets={'10': Num_Set_A, '01': Num_Set_B}, set_labels = ('Set A', 'Set B'))
c = venn2_circles(subsets=(Num_Set_A, Num_Set_B, 0), linestyle='solid')

v.get_patch_by_id('10').set_alpha(0.5)
v.get_patch_by_id('10').set_color('r')
v.get_patch_by_id('01').set_alpha(0.5)
v.get_patch_by_id('01').set_color('gray')
v.get_label_by_id('10').set_text('')
v.get_label_by_id('01').set_text('')
v.get_label_by_id('A').set_text('A')
v.get_label_by_id('B').set_text('B')

plt.gca().set_axis_on()

# %% [markdown]
# ## 1-6. 확률의 성질들
# 집합의 연산을 확률에 대응하여 살펴봅시다. 아래의 사건
# A, B 가 나타날 확률은 각각
# P(A), P(B) 입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1-7. 조건부확률 & 확률의 곱셈정리
# #### 조건부확률
# 확률이 0 이 아닌 두 사건 A와 B에 대하여 사건 A가 일어났을 때, 사건 B가 일어날 확률을 사건 A가 일어났을 때의 사건 B의 조건부확률(conditional probability) 이라 하고,
# P(B∣A)로 표현합니다. P(B∣A)는 다음과 같이 정의합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 두 개의 주사위를 차례로 던져 나오는 수의 합을 계산하는 실험을 한다고 해봅시다. 우리는 그 중에서 첫번째로 던진 주사위에서
# 4가 나오며 두 수의 합이 7이되는 사건을 원한다고 하겠습니다. 그럼 먼저 4가 첫번째로 나올 경우는 (4,1),(4,2),(4,3),(4,4),(4,5),(4,6)이며, 이는 가능한 경우의 수
# 36가지 중 6가지 입니다.
#
# ![image.png](attachment:image.png)
#
# 이제 첫번째 주사위에서 4가 나오는 사건을 A라고 하고, 주사위의 두 수의 합이 7이 되는 사건을 B라고 하겠습니다. 그럼 정의에 따라 다음과 같이 정리할 수 있습니다.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 확률의 곱셈정리
# 확률이 0이 아닌 두 사건 A와 B에 대해 조건부 확률 P(A∣B)과P(B∣A)는 정의에 따라
#
# ![image.png](attachment:image.png)
#
# 이므로, 이를 정리하면 다음과 같은 식을 얻을 수 있습니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 이것이 확률의 곱셈정리입니다.

# %% [markdown]
# Q. 첫 번째 주사위에서 짝수가 나오는 사건을 A, 두 주사위의 숫자 합이 홀수가 되는 사건을 B라고 할 때, P(B∣A)를 구하세요.
# 1/2
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1-8. 전확률과 베이즈 정리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1-9. 상호 배타적(배반) 사건과 독립사건의 차이
# ### 독립
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 상호 배타적(배반) 사건과 독립사건의 차이
# ---
# 먼저 의미적으로 접근해 봅시다.
#
# - 상호 배타적 사건 : 시행의 모든 시도에서 A 혹은 B사건이 발생했을 때 다른 하나의 사건이 발생하지 않을 경우 A와 는 서로 배타적(mutually exclusive) 입니다.
#
# - 독립 사건 : 두 사건 A, B에 대해서 한 사건이 다른 하나의 사건에 영향을 주지 않을 때 'A 와 B는 독립(independent) 이다' 라고 합니다.
#
# 그렇다면 A와 B는 독립 사건일까요?
#
# 동전을 던졌을 때 앞면이 나오는 것은 동전을 던졌을 때 뒷면이 나오는 것에 영향을 주지 않아 보이기 때문에 의미적으로 A와 B는 독립인 것처럼 생각됩니다.
# 하지만 앞서 가정했듯이 우리는 동전 하나를 '한번씩 던지는 실험'을 하고있습니다. 즉, 두 사건이 독립임을 알아보기 위해서 우리는 '동전 하나를 던졌을 때 뒷면이 나오는 조건하에 앞면이 나오는 경우'을 보아야 하는 것입니다.
# 그럼 뒷면이면서 앞면인 경우가 있을까요? 없습니다! '동전 하나를 던졌을 때 뒷면이 나오는 조건'이 붙었기 때문에 동전 던지기를 했을 때 동전은 뒷면이 나와 있어야 하며, 이 경우에 앞면이 나올 경우는 없어(∅)집니다.
# 즉, A의 사건이 B 사건에 영향을 받아 나올 수 없는 경우가 되었기에 A와 B는 종속 사건입니다.
#
# 이를 수식적으로 접근해 봅시다.
#
# H를 앞면이 나올 경우, T를 뒷면이 나올 경우라고 하겠습니다. 그러면,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q. 그러면 독립 사건에는 어떤 것들이 있을까요? 한번 생각해 봅시다.
#
# 두 개의 서로 다른 주사위 던지기
# 첫 번째 주사위에서 5가 나오는 사건과 두 번째 주사위에서 짝수가 나오는 사건은 독립적입니다. 첫 번째 주사위의 결과는 두 번째 주사위의 결과에 영향을 주지 않습니다.
#
# ![image.png](attachment:image.png)
