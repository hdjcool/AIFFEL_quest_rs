# %% [markdown]
# #### 학습 목표
# ----
# - 정칙화(Regularization)의 개념을 이해하고 정규화(Normalization)와 구분합니다.
# - L1 regularization과 L2 regularization의 차이를 설명합니다.
# - 실습을 통하여 Lp norm, Dropout, Batch Normalization에 대해 학습합니다.

# %% [markdown]
# #### 목차
# ---
# 1. 들어가며
# 2. Regularization과 Normalization
# 3. L1 Regularization
# 4. L2 Regularization
# 5. Extra : Lp norm
# 6. Dropout
# 7. Batch Normalization

# %% [markdown]
# ## 5-2. Regularization과 Normalization
# ---
# Regularization과 Normalization 이 두 개념은 서로 헷갈리는 경우가 많은 것 같습니다. 한국어로 번역할 때 두 개념이 다 '정규화'로 번역될 때가 많아서 더욱 혼란스러울 때가 많습니다. 우선 두 개념을 아래와 같이 정리해 보겠습니다.
#
# #### Regularization(정칙화)
# ---
# 정칙화라고 불리며, 오버피팅(overfitting)을 해결하기 위한 방법 중의 하나입니다. 오늘 우리가 가장 중요하게 다룰 주제이기도 하지요. L1, L2 Regularization, Dropout, Batch normalization 등이 있습니다. 오버피팅은 한국어로 과적합이라고 하며, train set은 매우 잘 맞히지만, validation/test set은 맞히지 못하는 현상을 말합니다. 비유하자면 오버피팅은 기출문제는 외워서 잘 맞히지만 새로운 응용 문제로 시험을 볼 때는 잘 풀지 못하는 경우라고 할 수 있겠습니다. 더 좋은 결과를 얻기 위해서는 새로운 시험, 즉 test set에서도 잘 맞혀야겠죠? 그래서 regularization 기법들은 모델에 제약 조건을 걸어서 모델의 train loss를 증가시키는 역할을 합니다. 그래서 train loss는 약간 증가하지만 결과적으로, validation loss나 최종 test loss를 감소시키려는 목적을 가지고 있지요.
#
# #### Normalization(정규화)
# ---
# 정규화라고 불리며, 이는 데이터의 형태를 좀 더 의미 있게, 혹은 트레이닝에 적합하게 전처리하는 과정입니다. 데이터를 z-score로 바꾸거나 minmax scaler를 사용하여 0과 1사이의 값으로 분포를 조정하는 것들이 해당됩니다. 예를 들어, 금액과 같은 큰 범위의 값(10,000 ~ 10,000,000)과 시간(0~24)의 값이 들어가는 경우, 데이터의 분포가 피처(feature) 값의 범위에 의해 왜곡되어 학습에 방해가 된다는 문제가 있습니다. normalization은 모든 피처 값의 범위를 동일하게 하여 모델이 풀어야 하는 문제를 좀 더 간단하게 바꾸어 주는 전처리 과정입니다.
#
# 이 두 가지 단어는 한국어로 번역 시에 혼용하여 쓰기도 하므로, 앞으로 이번 노드에서는 주로 영어로 표기하도록 하겠습니다. 핵심을 정리하면, regularization은 오버피팅을 막고자 하는 방법, normalization은 트레이닝을 할 때에 서로 범위가 다른 데이터들을 같은 범위로 바꿔주는 전처리 과정이라는 것입니다.
#
# Regularization와 Normalization의 간단한 예제를 Iris dataset의 회귀 문제를 풀면서 비교해 보겠습니다.

# %%
from sklearn.datasets import load_iris
import pandas as pd 
import matplotlib.pyplot as plt

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
target_df = pd.DataFrame(data=iris.target, columns=['species'])

# 0, 1, 2로 되어있는 target 데이터를 
# 알아보기 쉽게 'setosa', 'versicolor', 'virginica'로 바꿉니다 
def converter(species):
    if species == 0:
        return 'setosa'
    elif species == 1:
        return 'versicolor'
    else:
        return 'virginica'

target_df['species'] = target_df['species'].apply(converter)

iris_df = pd.concat([iris_df, target_df], axis=1)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# Iris data 중 virginica라는 종의 petal length(꽃잎 길이)를 X, sepal length(꽃받침의 길이)를 Y로 두고 print 해보겠습니다.

# %%
X = [iris_df['petal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']
Y = [iris_df['sepal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']

print("petal length(꽃잎 길이)", X)
print("sepal length(꽃받침의 길이)", Y)
# Out:
# petal length(꽃잎 길이) [6.0, 5.1, 5.9, 5.6, 5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5.0, 5.1, 5.3, 5.5, 6.7, 6.9, 5.0, 5.7, 4.9, 6.7, 4.9, 5.7, 6.0, 4.8, 4.9, 5.6, 5.8, 6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5.0, 5.2, 5.4, 5.1]
# sepal length(꽃받침의 길이) [6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]

# %% [markdown]
# 값으로만 보니 직관적으로 잘 와닿지 않네요! 산점도로 그려봅시다.
#
# 아직 normalization을 하지 않았기 때문에 x축과 y축은 각각의 최솟값과 최댓값의 범위로 그려집니다.

# %%
plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.title('petal-sepal scatter before normalization') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %% [markdown]
# 그래프의 축을 잘 살펴보세요!
#
# 이제 0-1로 normalization을 해주는 minmax_scale를 이용해서 산점도를 다시 한번 그려보겠습니다.

# %%
from sklearn.preprocessing import minmax_scale

X_scale = minmax_scale(X)
Y_scale = minmax_scale(Y)

plt.figure(figsize=(5,5))
plt.scatter(X_scale,Y_scale)
plt.title('petal-sepal scatter after normalization') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %% [markdown]
# 결과를 비교해 보면, 가장 큰 값을 1, 가장 작은 값을 0으로 하여 축 범위가 바뀜을 확인할 수 있습니다. 데이터의 상대적인 분포는 바뀌지 않았지만, 피처의 스케일이 0과 1 사이로 변환되었으므로 이후 X, Y의 관계를 다루기 용이해졌습니다.
#
# 이번엔 같은 데이터로 간단한 회귀 문제를 풀면서 regularization에 대해 알아보겠습니다.
#
# sklearn.linear_model에 포함된 LinearRegression 모델을 사용하여 X-Y 관계를 선형으로 모델링해 보겠습니다. 이 sklearn.linear_model에는 L1, L2 regression인 Lasso와 Ridge 모델도 함께 포함되어 있으므로, 이들의 차이점을 먼저 직관적으로 이해해 보겠습니다. 수학적 정의나 보다 구체적인 설명은 다음 스텝에 이어집니다.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np 

X = np.array(X)
Y = np.array(Y)

# Iris Dataset을 Linear Regression으로 학습합니다. 
linear= LinearRegression()
linear.fit(X.reshape(-1,1), Y)

# Linear Regression의 기울기와 절편을 확인합니다. 
a, b=linear.coef_, linear.intercept_
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))
# Out:
# 기울기 : 1.00, 절편 : 1.06

# %% [markdown]
# 위에서 linear regression으로 구한 기울기와 절편을 가지고 일차함수를 만들어 산점도와 함께 그려보겠습니다.

# %%
plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.plot(X,linear.predict(X.reshape(-1,1)),'-b')
plt.title('petal-sepal scatter with linear regression') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %% [markdown]
# 이번에는 L1, L2 regularization으로 regression을 해보겠습니다. 이는 Lasso, Ridge라고 부릅니다.
#
# 먼저 L1 regularization인 Lasso로 문제를 풀어보겠습니다.

# %%
# Q. linear regression의 코드를 참고하여, 아래 코드를 채워주세요!

# L1 regularization은 Lasso로 import 합니다.
from sklearn.linear_model import Lasso

L1 = Lasso()
# [[YOUR CODE]]
L1.fit(X.reshape(-1,1), Y)

# 기울기와 절편 계산
a, b = L1.coef_[0], L1.intercept_# [[YOUR CODE]]
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))

plt.figure(figsize=(5,5))
# [[YOUR CODE]]
plt.scatter(X,Y)
plt.plot(X,L1.predict(X.reshape(-1,1)),'-b')
plt.title('petal-sepal scatter with L1 regularization(Lasso)') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()
# Out:
# 기울기 : 0.00, 절편 : 6.59

# %% [markdown]
# 어떤가요? 혹시 기울기가 0으로 나오지 않았나요? Lasso 방법은 결과가 별로 좋지 않은 것 같습니다.
#
# 이제 같은 데이터셋으로 L2 regularization인 Ridge로 문제를 풀어보고 서로 비교해 보겠습니다.

# %%
# Q. linear regression의 코드를 참고하여, 아래 코드를 채워주세요!

# L2 regularization은 Ridge로 import 합니다.
from sklearn.linear_model import Ridge

L2 = Ridge()
# [[YOUR CODE]]
L2.fit(X.reshape(-1,1), Y)
a, b = L2.coef_[0], L2.intercept_# [[YOUR CODE]]
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))

plt.figure(figsize=(5,5))
# [[YOUR CODE]]
plt.scatter(X,Y)
plt.plot(X,L2.predict(X.reshape(-1,1)),'-b')
plt.title('petal-sepal scatter with L2 regularization(Ridge)') 
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()
# Out:
# 기울기 : 0.93, 절편 : 1.41

# %% [markdown]
# 다시 다루겠지만, linear regression이 L2 norm과 관련이 있습니다. 그래서 L2 regularization을 쓰는 Ridge방법으로는 앞서 linear regression과 큰 차이가 없는 결과가 나옵니다.
# 그러나 왜 L1 regularization을 쓰는 Lasso에서는 이상한 결과가 나왔을까요?
#
# 다음 스텝에서 그 이유를 알아보도록 하겠습니다!

# %% [markdown]
# ## 5-3. L1 Regularization
#
# 이전 스텝에서 regularization과 normalization의 정의를 설명하고, L1/L2 regularization을 코드로 맛보기 해보았습니다. 마지막에 같은 linear regression 문제를 푸는데 L1 regularization에서는 문제가 풀리지 않았다는 것을 기억하시나요?
#
# L1 regularization을 설명하면서, 지난 스텝에서 Lasso로는 regression 문제가 제대로 풀리지 않았던 현상을 더 자세히 알아보겠습니다. 그리고 어떤 때에 L1 regularization을 사용하는지 알아보는 것이 목표입니다!
#
# #### L1 regularization (Lasso)의 정의
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import load_iris
import pandas as pd 
import matplotlib.pyplot as plt

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
target_df = pd.DataFrame(data=iris.target, columns=['species'])

def converter(species):
    if species == 0:
        return 'setosa'
    elif species == 1:
        return 'versicolor'
    else:
        return 'virginica'

target_df['species'] = target_df['species'].apply(converter)

iris_df = pd.concat([iris_df, target_df], axis=1)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
X = [iris_df['petal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']
Y = [iris_df['sepal length (cm)'][a] for a in iris_df.index if iris_df['species'][a]=='virginica']

X = np.array(X)
Y = np.array(Y)

plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()

# %%
from sklearn.linear_model import Lasso

L1 = Lasso()
L1.fit(X.reshape(-1,1), Y)
a, b = L1.coef_, L1.intercept_
print("기울기 : %0.2f, 절편 : %0.2f" %(a,b))

plt.figure(figsize=(5,5))
plt.scatter(X,Y)
plt.plot(X,L1.predict(X.reshape(-1,1)),'-b')
plt.xlabel('petal length (cm)')
plt.ylabel('sepal length (cm)')
plt.grid()
plt.show()
# Out:
# 기울기 : 0.00, 절편 : 6.59

# %% [markdown]
# 흠... 기울기가 0으로 나오는 것이 아무래도 이상한데요...🤔
# 아무래도 데이터의 feature 개수가 2개밖에 되지 않으니까 이게 맞는 건지 아직 잘 모르겠습니다. 일단 다른 데이터셋으로 L1 regularization을 한번 더 돌려보겠습니다.

# %% [markdown]
# #### 컬럼 수가 많은 데이터에서의 L1 regularization 비교
# ---
# Iris 데이터는 특성이 총 4개로 컬럼 수가 너무 적으니 wine dataset을 이용해 보겠습니다.
# 총 13개의 특성을 갖는 데이터입니다.

# %%
from sklearn.datasets import load_wine

wine = load_wine()
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
target_df = pd.DataFrame(data=wine.target, columns=['Y'])

# %%
wine_df.head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
target_df.head(5)
# Out:
#    Y
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %% [markdown]
# 먼저 linear regression 으로 문제를 풀고, 그 계수(coefficient)와 절대 오차(mean absolute error), 제곱 오차(mean squared error), 평균 제곱값 오차(root mean squared error)를 출력해 보겠습니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 데이터를 준비하고
X_train, X_test, y_train, y_test = train_test_split(wine_df, target_df, test_size=0.3, random_state=101)

# 모델을 훈련시킵니다.
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트를 해볼까요?
pred = model.predict(X_test)

# 테스트 결과는 이렇습니다!
print("result of linear regression")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient linear regression")
print(model.coef_)
# Out:
# result of linear regression
# Mean Absolute Error: 0.25128973939722626
# Mean Squared Error: 0.1062458740952556
# Mean Root Squared Error: 0.32595379134971814
#
#
#  coefficient linear regression
# [[-8.09017190e-02  4.34817880e-02 -1.18857931e-01  3.65705449e-02
#   -4.68014203e-04  1.41423581e-01 -4.54107854e-01 -5.13172664e-01
#    9.69318443e-02  5.34311136e-02 -1.27626604e-01 -2.91381844e-01
#   -5.72238959e-04]]

# %% [markdown]
# 이번에는 L1 regularization으로 문제를 풀어보겠습니다.

# %%
# Q. 위의 Iris 예제 코드를 참고해서, 빈칸을 채워봅시다.

from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error

# 모델을 준비하고 훈련시킵니다.
L1 = Lasso(alpha=0.05)
# [[YOUR CODE]]
L1.fit(X_train, y_train)

# 테스트를 해봅시다.
pred = L1.predict(X_test) # [[YOUR CODE]]

# 모델 성능은 얼마나 좋을까요?
print("Result of Lasso")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred)) # [[YOUR CODE]])
print('Mean Squared Error:', mean_squared_error(y_test, pred)) # [[YOUR CODE]])
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred))) # [[YOUR CODE]])

print("\n\n coefficient of Lasso")
print(L1.coef_) # (# [[YOUR CODE]])
# Out:
# Result of Lasso
# Mean Absolute Error: 0.24233731936122138
# Mean Squared Error: 0.0955956894578189
# Mean Root Squared Error: 0.3091855259513597
#
#
#  coefficient of Lasso
# [-0.          0.01373795 -0.          0.03065716  0.00154719 -0.
#  -0.34143614 -0.          0.          0.06755943 -0.         -0.14558153
#  -0.00089635]

# %% [markdown]
# #### 결과 분석
# ---
# coefficient 부분을 보시면 linear regression과 L1 regularization의 차이가 좀 더 두드러짐을 알 수 있습니다. linear regression에서는 모든 컬럼의 가중치가 0이 아닌 값을 가지고 있지만, L1 regularization에서는 총 13개 중 7개를 제외한 나머지의 값들이 모두 0임을 확인할 수 있습니다. error 부분에서는 큰 차이가 없었지만, 우리가 어떤 컬럼이 결과에 영향을 더 크게 미치는지 확실히 확인할 수 있습니다. 이러한 경우 다른 문제에서도 error의 차이가 크게 나지 않는다면, 차원 축소와 비슷한 개념으로 변수의 값을 7개만 남겨도 충분히 결과를 예측할 수 있습니다. 다만 linear regression과 L1, L2 regularization의 차이 중 하나는 하이퍼파라미터(수식에서는 λ)가 하나 더 들어간다는 것이고, 그 값에 따라 error에 영향을 미친다는 점입니다.

# %% [markdown]
# ## 5-4. L2 Regularization
# #### L2 Regularization(Ridge)의 정의
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### L1 / L2 Regularization의 차이점
# ----
# L1 regularization이 L2 regularization과 다르게 왜 일부 컬럼의 가중치를 0으로 보내는지 증명하는 내용은 이 노드의 범위를 벗어나기 때문에, 대략적으로만 설명해 보겠습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [https://en.wikipedia.org/wiki/Lasso_(statistics)]

# %% [markdown]
# 위 그림에서, L1 regularization(왼쪽)은
# ∣
# w
# 1
# ∣
# +
# ∣
# w
# 2
# ∣
# 의 값을 최소화하는 것이 목적이므로 마름모 형태의 제약 조건이 생깁니다. 그리고 빨간색 직선은 우리가 풀어야 하는 문제의 해답이 될 수 있는 파라미터
# (
# w
# 1
# ,
# w
# 2
# )
# 들의 집합입니다. 마름모의 크기를 점점 늘렸을 때 (
# ∣
# w
# 1
# ∣
# +
# ∣
# w
# 2
# ∣
# 의 값을 증가시켰을 때), 이 직선('정답 파라미터 집합')이 마름모와 만나는 지점이 바로
# ∣
# w
# 1
# ∣
# +
# ∣
# w
# 2
# ∣
# 의 값을 최소화하는 해가 됩니다. L1 regularization은 제약 조건이 꼭지점이 각 축 위에 있는 마름모 모양이기 때문에, '정답 파라미터 집합'과 만나는 지점 역시 축 위에 있을 가능성이 높습니다. 좌표계에서 어떤 점이 축 위에 있다면 몇 개의 좌표는 0 값을 가지게 되죠. 그래서 L1 regularization의 결과를 보면 모델의 일부 coefficient 값이 0으로 나오는 것을 확인할 수 있습니다. 이전 스텝의 Iris dataset 예제에서는 기울기 값이 0으로 나왔고, wine dataset 예제에서도 몇 개의 coefficient가 0으로 바뀌었습니다.
#
# 이와 다르게 L2 regularization은
# w
# 1^
# 2
# +
# w
# 2^
# 2
# 값을 최소화하므로 제약 조건이 원의 형태로 나타나게 됩니다. 그러므로 직선과 만나는 지점이 축 위에 있을 가능성보다, 축과 가까운 다른 곳에 있을 가능성이 높습니다. wine dataset 예제에서도 L2 regularization 결과에서는 coefficient가 모두 0이 아닌 값을 가지고 있었죠. 또한 제곱이 들어가 있기 때문에 절댓값으로 L1 norm을 쓰는 Lasso보다는 수렴이 빠르다는 장점이 있습니다. 이는 이전과 같은 문제에서 iteration 조건을 추가하여 실험해보겠습니다.
#
# 바로 직관적으로 이해하기 쉽지 않죠? 조금 더 직관적으로 이해하고 싶다면 아래 블로그를 참고해주세요
#
# 정규화에 대해 자세하게 알아보자! https://modulabs.co.kr/blog/learn-about-regularization/

# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

wine = load_wine()
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
target_df = pd.DataFrame(data=wine.target, columns=['Y'])
X_train, X_test, y_train, y_test = train_test_split(wine_df, target_df, test_size= 0.3, random_state=101)
print('=3')
# Out:
# =3

# %%
from sklearn.linear_model import Lasso

L1 = Lasso(alpha=0.05, max_iter=5)
L1.fit(X_train, y_train)
pred = L1.predict(X_test)

print("result of Lasso")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient of Lasso")
print(L1.coef_)
# Out:
# result of Lasso
# Mean Absolute Error: 0.24845768841769436
# Mean Squared Error: 0.10262989110341268
# Mean Root Squared Error: 0.32035900346862844
#
#
#  coefficient of Lasso
# [-0.          0.         -0.          0.03295564  0.00109495  0.
#  -0.4027847   0.          0.          0.06023131 -0.         -0.12001119
#  -0.00078971]
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:645: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.924e+00, tolerance: 7.480e-03
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# L2 regularization도 같은 제약조건을 두고 문제를 풀어보겠습니다.

# %%
# Q. L1 regularization 코드를 참고하여 아래 코드를 채워주세요.

from sklearn.linear_model import Ridge

# [[YOUR CODE]]
L2 = Ridge(alpha=0.05, max_iter=5)
L2.fit(X_train, y_train)
pred = L2.predict(X_test)

print("result of Ridge")
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(y_test, pred)))

print("\n\n coefficient of Ridge")
print(L2.coef_)
# Out:
# result of Ridge
# Mean Absolute Error: 0.251146695993643
# Mean Squared Error: 0.10568076460795564
# Mean Root Squared Error: 0.3250857803841251
#
#
#  coefficient of Ridge
# [[-8.12456257e-02  4.35541496e-02 -1.21661565e-01  3.65979773e-02
#   -3.94014013e-04  1.39168707e-01 -4.50691113e-01 -4.87216747e-01
#    9.54111059e-02  5.37077039e-02 -1.28602933e-01 -2.89832790e-01
#   -5.73136185e-04]]

# %% [markdown]
# iteration 값을 5로만 설정해 보아도, L2 regularization의 결과는 linear regression과 같은 값이 나오지만, L1 regularization에서는 앞 step과 같은 값을 확인할 수는 없었습니다. 심지어 수렴하지 않았다는 경고까지 나오는군요! 이는 아직 다른 조건들을 만족하는 답을 찾지 못하였다는 뜻입니다.
#
# 정리하면, L1 regularization은 가중치가 적은 벡터에 해당하는 계수를 0으로 보내면서 차원 축소와 비슷한 역할을 하는 것이 특징이며, L2 regularization은 계수를 0으로 보내지는 않지만 제곱 텀이 있기 때문에 L1 regularization보다는 수렴 속도가 빠르다는 장점이 있습니다. 예를 들어, A=[1,1,1,1,1] , B=[5,0,0,0,0] 의 경우 L1-norm은 같지만, L2-norm은 같지 않습니다. 즉, 제곱 텀에서 결과에 큰 영향을 미치는 값은 더 크게, 결과에 영향이 적은 값들은 더 작게 보내면서 수렴 속도가 빨라지는 것입니다.
#
# 그러므로, 데이터에 따라 적절한 regularization 방법을 활용하는 것이 좋습니다.

# %% [markdown]
# ## 5-5. Extra : Lp norm
#
# 이전 스텝에서 잠깐 소개해드린 Lp norm에 대해 자세히 설명하겠습니다.
# Norm이라는 용어는 벡터뿐만 아니라 함수, 행렬의 크기를 나타내는 개념으로, 딥러닝을 배우는 과정에서는 주로 벡터, 좀 더 어렵게는 행렬의 norm 정도만 알면 됩니다.
#
# #### Vector norm
# ----

# %% [markdown]
# L1 / L2 regularization에서 배운 norm은 벡터에서 정의된 norm으로 아래와 같습니다.
# ![image.png](attachment:image.png)

# %% [markdown]
# 아래 코드에서 p의 값과 x의 형태를 바꾸어가며 실험해 보세요.

# %%
# [Playground] x와 p를 바꾸어가며 norm 값이 어떻게 변하는지 실험해봅시다!
# --------------------------- #
x = np.array([1,10,1,1,1])
p = 5
# --------------------------- #

norm_x = np.linalg.norm(x, ord=p)
making_norm = (sum(x**p))**(1/p)
print("result of numpy package norm function : %0.5f "%norm_x) 
print("result of making norm : %0.5f "%making_norm)
# Out:
# result of numpy package norm function : 10.00008
# result of making norm : 10.00008

# %% [markdown]
# p=1이면 맨해튼 거리 (절대값의 합), p=2이면 유클리디안 거리 (제곱합의 제곱근)를 의미하며, p가 클수록 벡터에서 가장 큰 요소의 크기가 노름에 큰 영향을 미치게 됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
norm_x = np.linalg.norm(x, ord=np.inf)
print("result of infinite norm : %0.5f "%norm_x)
# Out:
# result of infinite norm : 10.00000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = np.array([[1,2,3], [1,2,3], [4,6,8]])

one_norm_A = np.linalg.norm(A, ord=1)
print("result one norm of A :", one_norm_A)

inf_norm_A = np.linalg.norm(A, ord=np.inf)
print("result inf norm of A :", inf_norm_A)
# Out:
# result one norm of A : 14.0
# result inf norm of A : 18.0

# %% [markdown]
# 추가 설명:
# 행렬의 노름은 벡터의 노름과는 다르게 정의됩니다.
#
# 1-노름(컬럼 노름) (ord=1)은 각 열의 원소 합 중에서 가장 큰 값을 반환합니다. 이는 각 열의 절대값 합을 계산하고, 그 중 최대값을 선택합니다. 따라서 가장 큰 합을 가지는 열을 기준으로 행렬의 크기를 정의합니다.
#
# 무한 노름(행 노름) (ord=np.inf)은 각 행의 원소 합 중에서 가장 큰 값을 반환합니다. 각 행의 절대값 합을 계산하고 그 중 최대값을 사용하여 행렬의 크기를 정의합니다.
#
# 이는 행렬의 특정 차원을 기준으로 최대 절대합을 고려하여 행렬의 크기를 측정하는 방법입니다.

# %% [markdown]
# ## 5-6. Dropout
#
# 드롭아웃(Dropout) 기법은 2014년도에 나온 논문입니다.
#
# 논문 제목 : Dropout: A Simple Way to Prevent Neural Networks from Overfitting
# 논문 발표 시점 : 2014년
# 논문 링크 : 논문 주소
#
# 드롭아웃 기법이 나오기 전의 신경망은 fully connected architecture로 모든 뉴런들이 연결되어 있었습니다.
#
# 드롭아웃이란 확률적으로 랜덤하게 몇 가지의 뉴런만 선택하여 정보를 전달하는 과정입니다. 이름 그대로 몇 가지의 값들을 모든 뉴런에 전달하는 것이 아닌, 확률적으로 버리면서 전달하는 기법입니다. 드롭아웃은 오버피팅을 막는 regularization layer 중 하나입니다. 확률을 너무 높이면 (비활성화된 뉴런의 비중을 높이면) 모델 안에서 값들이 제대로 전달되지 않으므로 학습이 잘 되지 않고, 확률을 너무 낮추는 경우에는 fully connected layer와 같이 동작합니다. fully connected layer에서 오버피팅이 생기는 경우에 주로 dropout layer를 추가합니다.
#
# 코드는 간단합니다. 논문이 나온 지도 오래되었기 때문에, 여러 프레임워크에서 간단하게 구현할 수 있도록 되어있습니다.
#
# - Keras Dropout https://keras.io/api/layers/regularization_layers/dropout/
#
# #### 실습 (not overfitting)
# ---
# fashion mnist라는 데이터 셋을 불러와서 학습을 시키도록 하겠습니다. 이 데이터셋은 총 10개의 클래스로 구성되어 있고, 데이터가 간단한 편이기도 하여 5 epoch 정도만 학습시켜도 어느 정도 결과가 나옵니다. 드롭아웃 레이어를 중간에 추가하여 확률을 1에 가깝게 주면 어떻게 되는지 살펴보도록 하겠습니다.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

fashion_mnist = keras.datasets.fashion_mnist
print('=3')
# Out:
# =3

# %% [markdown]
# dropout의 확률을 0.9로 주었을 때의 결과를 살펴보도록 하겠습니다.

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# dropout이 없을 때 실습을 해보면, 5 epoch 정도만 돌려도 충분히 높은 정확도를 볼 수 있습니다.

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    # 여기에 dropout layer를 추가해보았습니다. 나머지 layer는 아래의 실습과 같습니다.
    keras.layers.Dropout(0.9),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history= model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 1.3666 - accuracy: 0.4679
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 1.1433 - accuracy: 0.5375
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 1.0913 - accuracy: 0.5598
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.0489 - accuracy: 0.5741
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.0382 - accuracy: 0.5772

# %% [markdown]
# 현재 이 데이터 셋은 학습이 잘 되는 데이터 셋으로, fully connected layer에서도 결과가 잘 나옴을 확인할 수 있는데요. 일부러 중간에 dropout layer를 추가하여 0.9의 확률 값을 주니 학습이 안 됨을 확인하였습니다. 다음은 overfitting이 나는 환경에서 dropout의 중요성을 알아보도록 하겠습니다.

# %% [markdown]
# #### 실습 (overfitting)
# ---
# overfitting이 되는지 확인해 보려면 train set과 validation set의 loss function을 그려보는 것이 가장 첫 번째 시도입니다. 우리는 위의 데이터를 이제 train:valid=99:1의 비율로 나눈 뒤에 loss function의 값을 그려보고, overfitting이 생기는 fully connected layer를 만들어보도록 합시다. overfitting이 되게 하기 위해 의도적으로 train set을 99%로 늘리고 validation set을 줄였습니다.
#
# 📖 학습팁
#
# 아래 코드는 200 epoch이므로 코드가 돌아가는데 5분이상 소요됩니다. 그동안 overfitting에 대한 자료를 찾아보면서 기다려주세요!

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_images, train_labels, test_size=0.01, random_state=101)
X_train = X_train / 255.0
X_valid = X_valid / 255.0

# Dense layer만으로 만들어 낸 classification 모델입니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=200, batch_size=512, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/200
# 117/117 [==============================] - 5s 36ms/step - loss: 2.0517 - accuracy: 0.5517 - val_loss: 1.6431 - val_accuracy: 0.6150
# Epoch 2/200
# 117/117 [==============================] - 3s 29ms/step - loss: 1.3958 - accuracy: 0.6267 - val_loss: 1.1708 - val_accuracy: 0.6867
# Epoch 3/200
# 117/117 [==============================] - 3s 28ms/step - loss: 1.0648 - accuracy: 0.6883 - val_loss: 0.9470 - val_accuracy: 0.7350
# Epoch 4/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.8859 - accuracy: 0.7203 - val_loss: 0.8116 - val_accuracy: 0.7567
# Epoch 5/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.7833 - accuracy: 0.7379 - val_loss: 0.7409 - val_accuracy: 0.7750
# Epoch 6/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.7203 - accuracy: 0.7484 - val_loss: 0.6914 - val_accuracy: 0.7783
# Epoch 7/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.6778 - accuracy: 0.7599 - val_loss: 0.6537 - val_accuracy: 0.7800
# Epoch 8/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.6466 - accuracy: 0.7682 - val_loss: 0.6270 - val_accuracy: 0.7833
# Epoch 9/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.6207 - accuracy: 0.7776 - val_loss: 0.6058 - val_accuracy: 0.7933
# Epoch 10/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.5999 - accuracy: 0.7855 - val_loss: 0.5890 - val_accuracy: 0.7983
# Epoch 11/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.5823 - accuracy: 0.7929 - val_loss: 0.5746 - val_accuracy: 0.7983
# Epoch 12/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.5672 - accuracy: 0.7983 - val_loss: 0.5624 - val_accuracy: 0.7983
# Epoch 13/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.5533 - accuracy: 0.8044 - val_loss: 0.5458 - val_accuracy: 0.8017
# Epoch 14/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.5409 - accuracy: 0.8099 - val_loss: 0.5390 - val_accuracy: 0.8017
# Epoch 15/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.5305 - accuracy: 0.8141 - val_loss: 0.5296 - val_accuracy: 0.8050
# Epoch 16/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.5208 - accuracy: 0.8181 - val_loss: 0.5223 - val_accuracy: 0.8083
# Epoch 17/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.5124 - accuracy: 0.8197 - val_loss: 0.5113 - val_accuracy: 0.8133
# Epoch 18/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.5033 - accuracy: 0.8238 - val_loss: 0.5028 - val_accuracy: 0.8167
# Epoch 19/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4965 - accuracy: 0.8261 - val_loss: 0.4983 - val_accuracy: 0.8167
# Epoch 20/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4901 - accuracy: 0.8286 - val_loss: 0.4926 - val_accuracy: 0.8183
# Epoch 21/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4837 - accuracy: 0.8303 - val_loss: 0.4906 - val_accuracy: 0.8200
# Epoch 22/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4793 - accuracy: 0.8313 - val_loss: 0.4798 - val_accuracy: 0.8217
# Epoch 23/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4737 - accuracy: 0.8331 - val_loss: 0.4790 - val_accuracy: 0.8317
# Epoch 24/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4684 - accuracy: 0.8358 - val_loss: 0.4729 - val_accuracy: 0.8283
# Epoch 25/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4640 - accuracy: 0.8370 - val_loss: 0.4661 - val_accuracy: 0.8233
# Epoch 26/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4597 - accuracy: 0.8389 - val_loss: 0.4664 - val_accuracy: 0.8283
# Epoch 27/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4575 - accuracy: 0.8392 - val_loss: 0.4581 - val_accuracy: 0.8300
# Epoch 28/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4526 - accuracy: 0.8421 - val_loss: 0.4586 - val_accuracy: 0.8283
# Epoch 29/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4495 - accuracy: 0.8432 - val_loss: 0.4505 - val_accuracy: 0.8350
# Epoch 30/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.4465 - accuracy: 0.8432 - val_loss: 0.4503 - val_accuracy: 0.8233
# Epoch 31/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4430 - accuracy: 0.8456 - val_loss: 0.4483 - val_accuracy: 0.8283
# Epoch 32/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4402 - accuracy: 0.8458 - val_loss: 0.4429 - val_accuracy: 0.8300
# Epoch 33/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.4371 - accuracy: 0.8475 - val_loss: 0.4416 - val_accuracy: 0.8317
# Epoch 34/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4357 - accuracy: 0.8479 - val_loss: 0.4380 - val_accuracy: 0.8350
# Epoch 35/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4318 - accuracy: 0.8492 - val_loss: 0.4388 - val_accuracy: 0.8367
# Epoch 36/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4298 - accuracy: 0.8501 - val_loss: 0.4379 - val_accuracy: 0.8333
# Epoch 37/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4273 - accuracy: 0.8501 - val_loss: 0.4328 - val_accuracy: 0.8367
# Epoch 38/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4247 - accuracy: 0.8515 - val_loss: 0.4296 - val_accuracy: 0.8383
# Epoch 39/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4223 - accuracy: 0.8518 - val_loss: 0.4301 - val_accuracy: 0.8317
# Epoch 40/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4204 - accuracy: 0.8527 - val_loss: 0.4243 - val_accuracy: 0.8333
# Epoch 41/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4178 - accuracy: 0.8537 - val_loss: 0.4222 - val_accuracy: 0.8333
# Epoch 42/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4167 - accuracy: 0.8546 - val_loss: 0.4234 - val_accuracy: 0.8383
# Epoch 43/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4149 - accuracy: 0.8545 - val_loss: 0.4176 - val_accuracy: 0.8317
# Epoch 44/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4121 - accuracy: 0.8553 - val_loss: 0.4199 - val_accuracy: 0.8367
# Epoch 45/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4111 - accuracy: 0.8551 - val_loss: 0.4172 - val_accuracy: 0.8333
# Epoch 46/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4089 - accuracy: 0.8567 - val_loss: 0.4195 - val_accuracy: 0.8300
# Epoch 47/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4067 - accuracy: 0.8573 - val_loss: 0.4120 - val_accuracy: 0.8367
# Epoch 48/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.4049 - accuracy: 0.8579 - val_loss: 0.4073 - val_accuracy: 0.8333
# Epoch 49/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4035 - accuracy: 0.8584 - val_loss: 0.4104 - val_accuracy: 0.8333
# Epoch 50/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.4020 - accuracy: 0.8589 - val_loss: 0.4088 - val_accuracy: 0.8317
# Epoch 51/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.4007 - accuracy: 0.8591 - val_loss: 0.4027 - val_accuracy: 0.8350
# Epoch 52/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3986 - accuracy: 0.8602 - val_loss: 0.4086 - val_accuracy: 0.8317
# Epoch 53/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3967 - accuracy: 0.8606 - val_loss: 0.4014 - val_accuracy: 0.8367
# Epoch 54/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3962 - accuracy: 0.8610 - val_loss: 0.4008 - val_accuracy: 0.8350
# Epoch 55/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3939 - accuracy: 0.8615 - val_loss: 0.3977 - val_accuracy: 0.8350
# Epoch 56/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3926 - accuracy: 0.8618 - val_loss: 0.4039 - val_accuracy: 0.8300
# Epoch 57/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3907 - accuracy: 0.8627 - val_loss: 0.3954 - val_accuracy: 0.8417
# Epoch 58/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.3902 - accuracy: 0.8630 - val_loss: 0.3982 - val_accuracy: 0.8333
# Epoch 59/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3884 - accuracy: 0.8632 - val_loss: 0.3968 - val_accuracy: 0.8383
# Epoch 60/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3895 - accuracy: 0.8633 - val_loss: 0.3963 - val_accuracy: 0.8317
# Epoch 61/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3852 - accuracy: 0.8647 - val_loss: 0.3910 - val_accuracy: 0.8367
# Epoch 62/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3852 - accuracy: 0.8642 - val_loss: 0.3901 - val_accuracy: 0.8367
# Epoch 63/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3827 - accuracy: 0.8661 - val_loss: 0.3939 - val_accuracy: 0.8400
# Epoch 64/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3816 - accuracy: 0.8656 - val_loss: 0.3931 - val_accuracy: 0.8367
# Epoch 65/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3800 - accuracy: 0.8667 - val_loss: 0.3874 - val_accuracy: 0.8350
# Epoch 66/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3789 - accuracy: 0.8664 - val_loss: 0.3850 - val_accuracy: 0.8350
# Epoch 67/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3783 - accuracy: 0.8672 - val_loss: 0.3875 - val_accuracy: 0.8433
# Epoch 68/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3764 - accuracy: 0.8678 - val_loss: 0.3901 - val_accuracy: 0.8467
# Epoch 69/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3769 - accuracy: 0.8670 - val_loss: 0.3852 - val_accuracy: 0.8433
# Epoch 70/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3748 - accuracy: 0.8682 - val_loss: 0.3870 - val_accuracy: 0.8483
# Epoch 71/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3728 - accuracy: 0.8687 - val_loss: 0.3852 - val_accuracy: 0.8367
# Epoch 72/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3724 - accuracy: 0.8689 - val_loss: 0.3813 - val_accuracy: 0.8383
# Epoch 73/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3714 - accuracy: 0.8691 - val_loss: 0.3797 - val_accuracy: 0.8383
# Epoch 74/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3698 - accuracy: 0.8701 - val_loss: 0.3843 - val_accuracy: 0.8433
# Epoch 75/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3695 - accuracy: 0.8694 - val_loss: 0.3784 - val_accuracy: 0.8483
# Epoch 76/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3685 - accuracy: 0.8691 - val_loss: 0.3786 - val_accuracy: 0.8450
# Epoch 77/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3673 - accuracy: 0.8704 - val_loss: 0.3835 - val_accuracy: 0.8483
# Epoch 78/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3660 - accuracy: 0.8703 - val_loss: 0.3745 - val_accuracy: 0.8467
# Epoch 79/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3664 - accuracy: 0.8709 - val_loss: 0.3864 - val_accuracy: 0.8450
# Epoch 80/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3647 - accuracy: 0.8716 - val_loss: 0.3733 - val_accuracy: 0.8450
# Epoch 81/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3629 - accuracy: 0.8712 - val_loss: 0.3765 - val_accuracy: 0.8467
# Epoch 82/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3614 - accuracy: 0.8725 - val_loss: 0.3701 - val_accuracy: 0.8450
# Epoch 83/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3605 - accuracy: 0.8725 - val_loss: 0.3695 - val_accuracy: 0.8417
# Epoch 84/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3604 - accuracy: 0.8725 - val_loss: 0.3685 - val_accuracy: 0.8333
# Epoch 85/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3591 - accuracy: 0.8736 - val_loss: 0.3703 - val_accuracy: 0.8433
# Epoch 86/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3580 - accuracy: 0.8736 - val_loss: 0.3695 - val_accuracy: 0.8500
# Epoch 87/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3570 - accuracy: 0.8737 - val_loss: 0.3673 - val_accuracy: 0.8500
# Epoch 88/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3570 - accuracy: 0.8739 - val_loss: 0.3683 - val_accuracy: 0.8500
# Epoch 89/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3556 - accuracy: 0.8744 - val_loss: 0.3654 - val_accuracy: 0.8533
# Epoch 90/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3545 - accuracy: 0.8746 - val_loss: 0.3711 - val_accuracy: 0.8483
# Epoch 91/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3552 - accuracy: 0.8743 - val_loss: 0.3658 - val_accuracy: 0.8517
# Epoch 92/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3536 - accuracy: 0.8758 - val_loss: 0.3679 - val_accuracy: 0.8450
# Epoch 93/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3525 - accuracy: 0.8757 - val_loss: 0.3689 - val_accuracy: 0.8567
# Epoch 94/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.3512 - accuracy: 0.8756 - val_loss: 0.3648 - val_accuracy: 0.8500
# Epoch 95/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3499 - accuracy: 0.8762 - val_loss: 0.3623 - val_accuracy: 0.8517
# Epoch 96/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3493 - accuracy: 0.8764 - val_loss: 0.3666 - val_accuracy: 0.8517
# Epoch 97/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3479 - accuracy: 0.8768 - val_loss: 0.3633 - val_accuracy: 0.8517
# Epoch 98/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3484 - accuracy: 0.8765 - val_loss: 0.3633 - val_accuracy: 0.8483
# Epoch 99/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3465 - accuracy: 0.8773 - val_loss: 0.3633 - val_accuracy: 0.8483
# Epoch 100/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3454 - accuracy: 0.8778 - val_loss: 0.3593 - val_accuracy: 0.8467
# Epoch 101/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3452 - accuracy: 0.8785 - val_loss: 0.3643 - val_accuracy: 0.8533
# Epoch 102/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.3440 - accuracy: 0.8777 - val_loss: 0.3623 - val_accuracy: 0.8483
# Epoch 103/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3439 - accuracy: 0.8794 - val_loss: 0.3565 - val_accuracy: 0.8467
# Epoch 104/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.3425 - accuracy: 0.8788 - val_loss: 0.3642 - val_accuracy: 0.8550
# Epoch 105/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3422 - accuracy: 0.8789 - val_loss: 0.3549 - val_accuracy: 0.8550
# Epoch 106/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3410 - accuracy: 0.8793 - val_loss: 0.3580 - val_accuracy: 0.8533
# Epoch 107/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3409 - accuracy: 0.8797 - val_loss: 0.3596 - val_accuracy: 0.8517
# Epoch 108/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3409 - accuracy: 0.8789 - val_loss: 0.3602 - val_accuracy: 0.8533
# Epoch 109/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3385 - accuracy: 0.8796 - val_loss: 0.3583 - val_accuracy: 0.8467
# Epoch 110/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3385 - accuracy: 0.8801 - val_loss: 0.3549 - val_accuracy: 0.8550
# Epoch 111/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3370 - accuracy: 0.8813 - val_loss: 0.3609 - val_accuracy: 0.8583
# Epoch 112/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3367 - accuracy: 0.8810 - val_loss: 0.3554 - val_accuracy: 0.8483
# Epoch 113/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3356 - accuracy: 0.8812 - val_loss: 0.3532 - val_accuracy: 0.8567
# Epoch 114/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3355 - accuracy: 0.8816 - val_loss: 0.3539 - val_accuracy: 0.8500
# Epoch 115/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3358 - accuracy: 0.8800 - val_loss: 0.3560 - val_accuracy: 0.8533
# Epoch 116/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3347 - accuracy: 0.8807 - val_loss: 0.3607 - val_accuracy: 0.8617
# Epoch 117/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3335 - accuracy: 0.8819 - val_loss: 0.3507 - val_accuracy: 0.8483
# Epoch 118/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3320 - accuracy: 0.8829 - val_loss: 0.3510 - val_accuracy: 0.8550
# Epoch 119/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3316 - accuracy: 0.8821 - val_loss: 0.3496 - val_accuracy: 0.8567
# Epoch 120/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3314 - accuracy: 0.8824 - val_loss: 0.3507 - val_accuracy: 0.8483
# Epoch 121/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3306 - accuracy: 0.8828 - val_loss: 0.3515 - val_accuracy: 0.8583
# Epoch 122/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3295 - accuracy: 0.8832 - val_loss: 0.3521 - val_accuracy: 0.8483
# Epoch 123/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3288 - accuracy: 0.8834 - val_loss: 0.3555 - val_accuracy: 0.8583
# Epoch 124/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3291 - accuracy: 0.8831 - val_loss: 0.3496 - val_accuracy: 0.8517
# Epoch 125/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3278 - accuracy: 0.8846 - val_loss: 0.3472 - val_accuracy: 0.8550
# Epoch 126/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3276 - accuracy: 0.8844 - val_loss: 0.3481 - val_accuracy: 0.8517
# Epoch 127/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3269 - accuracy: 0.8836 - val_loss: 0.3520 - val_accuracy: 0.8633
# Epoch 128/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3257 - accuracy: 0.8848 - val_loss: 0.3477 - val_accuracy: 0.8583
# Epoch 129/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3249 - accuracy: 0.8861 - val_loss: 0.3458 - val_accuracy: 0.8600
# Epoch 130/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3244 - accuracy: 0.8855 - val_loss: 0.3488 - val_accuracy: 0.8533
# Epoch 131/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3236 - accuracy: 0.8856 - val_loss: 0.3494 - val_accuracy: 0.8617
# Epoch 132/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3241 - accuracy: 0.8852 - val_loss: 0.3485 - val_accuracy: 0.8500
# Epoch 133/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3230 - accuracy: 0.8855 - val_loss: 0.3440 - val_accuracy: 0.8550
# Epoch 134/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3215 - accuracy: 0.8860 - val_loss: 0.3480 - val_accuracy: 0.8600
# Epoch 135/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3218 - accuracy: 0.8868 - val_loss: 0.3443 - val_accuracy: 0.8550
# Epoch 136/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3203 - accuracy: 0.8865 - val_loss: 0.3463 - val_accuracy: 0.8550
# Epoch 137/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3198 - accuracy: 0.8864 - val_loss: 0.3437 - val_accuracy: 0.8583
# Epoch 138/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3191 - accuracy: 0.8871 - val_loss: 0.3431 - val_accuracy: 0.8583
# Epoch 139/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3198 - accuracy: 0.8871 - val_loss: 0.3506 - val_accuracy: 0.8583
# Epoch 140/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3180 - accuracy: 0.8878 - val_loss: 0.3463 - val_accuracy: 0.8617
# Epoch 141/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3171 - accuracy: 0.8885 - val_loss: 0.3481 - val_accuracy: 0.8617
# Epoch 142/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3173 - accuracy: 0.8880 - val_loss: 0.3425 - val_accuracy: 0.8633
# Epoch 143/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3168 - accuracy: 0.8877 - val_loss: 0.3498 - val_accuracy: 0.8600
# Epoch 144/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3152 - accuracy: 0.8879 - val_loss: 0.3512 - val_accuracy: 0.8650
# Epoch 145/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3163 - accuracy: 0.8879 - val_loss: 0.3370 - val_accuracy: 0.8650
# Epoch 146/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3148 - accuracy: 0.8885 - val_loss: 0.3434 - val_accuracy: 0.8617
# Epoch 147/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3145 - accuracy: 0.8888 - val_loss: 0.3413 - val_accuracy: 0.8617
# Epoch 148/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3143 - accuracy: 0.8884 - val_loss: 0.3424 - val_accuracy: 0.8667
# Epoch 149/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3151 - accuracy: 0.8887 - val_loss: 0.3469 - val_accuracy: 0.8617
# Epoch 150/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3123 - accuracy: 0.8889 - val_loss: 0.3400 - val_accuracy: 0.8700
# Epoch 151/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3129 - accuracy: 0.8890 - val_loss: 0.3397 - val_accuracy: 0.8617
# Epoch 152/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3110 - accuracy: 0.8904 - val_loss: 0.3388 - val_accuracy: 0.8650
# Epoch 153/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3117 - accuracy: 0.8895 - val_loss: 0.3401 - val_accuracy: 0.8700
# Epoch 154/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3098 - accuracy: 0.8913 - val_loss: 0.3389 - val_accuracy: 0.8700
# Epoch 155/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3098 - accuracy: 0.8901 - val_loss: 0.3385 - val_accuracy: 0.8600
# Epoch 156/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3090 - accuracy: 0.8905 - val_loss: 0.3436 - val_accuracy: 0.8750
# Epoch 157/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3087 - accuracy: 0.8903 - val_loss: 0.3360 - val_accuracy: 0.8667
# Epoch 158/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3078 - accuracy: 0.8913 - val_loss: 0.3372 - val_accuracy: 0.8633
# Epoch 159/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3077 - accuracy: 0.8910 - val_loss: 0.3395 - val_accuracy: 0.8650
# Epoch 160/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3077 - accuracy: 0.8912 - val_loss: 0.3381 - val_accuracy: 0.8700
# Epoch 161/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3065 - accuracy: 0.8913 - val_loss: 0.3419 - val_accuracy: 0.8667
# Epoch 162/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3066 - accuracy: 0.8914 - val_loss: 0.3367 - val_accuracy: 0.8667
# Epoch 163/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.3053 - accuracy: 0.8914 - val_loss: 0.3408 - val_accuracy: 0.8700
# Epoch 164/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3048 - accuracy: 0.8921 - val_loss: 0.3355 - val_accuracy: 0.8650
# Epoch 165/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3037 - accuracy: 0.8929 - val_loss: 0.3378 - val_accuracy: 0.8700
# Epoch 166/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3042 - accuracy: 0.8917 - val_loss: 0.3364 - val_accuracy: 0.8683
# Epoch 167/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3041 - accuracy: 0.8924 - val_loss: 0.3333 - val_accuracy: 0.8700
# Epoch 168/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3029 - accuracy: 0.8923 - val_loss: 0.3346 - val_accuracy: 0.8700
# Epoch 169/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3027 - accuracy: 0.8933 - val_loss: 0.3340 - val_accuracy: 0.8633
# Epoch 170/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3024 - accuracy: 0.8928 - val_loss: 0.3321 - val_accuracy: 0.8683
# Epoch 171/200
# 117/117 [==============================] - 3s 27ms/step - loss: 0.3019 - accuracy: 0.8928 - val_loss: 0.3364 - val_accuracy: 0.8700
# Epoch 172/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3015 - accuracy: 0.8936 - val_loss: 0.3356 - val_accuracy: 0.8700
# Epoch 173/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.3008 - accuracy: 0.8929 - val_loss: 0.3325 - val_accuracy: 0.8683
# Epoch 174/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.3001 - accuracy: 0.8937 - val_loss: 0.3311 - val_accuracy: 0.8633
# Epoch 175/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2994 - accuracy: 0.8941 - val_loss: 0.3323 - val_accuracy: 0.8750
# Epoch 176/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.2985 - accuracy: 0.8942 - val_loss: 0.3357 - val_accuracy: 0.8633
# Epoch 177/200
# 117/117 [==============================] - 3s 30ms/step - loss: 0.2988 - accuracy: 0.8941 - val_loss: 0.3344 - val_accuracy: 0.8733
# Epoch 178/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2980 - accuracy: 0.8941 - val_loss: 0.3334 - val_accuracy: 0.8750
# Epoch 179/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.2972 - accuracy: 0.8950 - val_loss: 0.3363 - val_accuracy: 0.8667
# Epoch 180/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2981 - accuracy: 0.8940 - val_loss: 0.3338 - val_accuracy: 0.8733
# Epoch 181/200
# 117/117 [==============================] - 3s 29ms/step - loss: 0.2963 - accuracy: 0.8949 - val_loss: 0.3286 - val_accuracy: 0.8683
# Epoch 182/200
# 117/117 [==============================] - 3s 26ms/step - loss: 0.2954 - accuracy: 0.8959 - val_loss: 0.3260 - val_accuracy: 0.8717
# Epoch 183/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2960 - accuracy: 0.8949 - val_loss: 0.3307 - val_accuracy: 0.8667
# Epoch 184/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2963 - accuracy: 0.8947 - val_loss: 0.3282 - val_accuracy: 0.8683
# Epoch 185/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2944 - accuracy: 0.8959 - val_loss: 0.3322 - val_accuracy: 0.8800
# Epoch 186/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2950 - accuracy: 0.8958 - val_loss: 0.3333 - val_accuracy: 0.8700
# Epoch 187/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2950 - accuracy: 0.8954 - val_loss: 0.3277 - val_accuracy: 0.8700
# Epoch 188/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2935 - accuracy: 0.8962 - val_loss: 0.3286 - val_accuracy: 0.8717
# Epoch 189/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2924 - accuracy: 0.8970 - val_loss: 0.3275 - val_accuracy: 0.8733
# Epoch 190/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2921 - accuracy: 0.8964 - val_loss: 0.3235 - val_accuracy: 0.8817
# Epoch 191/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2921 - accuracy: 0.8962 - val_loss: 0.3276 - val_accuracy: 0.8650
# Epoch 192/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2923 - accuracy: 0.8959 - val_loss: 0.3272 - val_accuracy: 0.8717
# Epoch 193/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.2907 - accuracy: 0.8963 - val_loss: 0.3334 - val_accuracy: 0.8767
# Epoch 194/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2911 - accuracy: 0.8968 - val_loss: 0.3293 - val_accuracy: 0.8700
# Epoch 195/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2903 - accuracy: 0.8968 - val_loss: 0.3294 - val_accuracy: 0.8667
# Epoch 196/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2903 - accuracy: 0.8973 - val_loss: 0.3374 - val_accuracy: 0.8717
# Epoch 197/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.2898 - accuracy: 0.8970 - val_loss: 0.3248 - val_accuracy: 0.8683
# Epoch 198/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2879 - accuracy: 0.8981 - val_loss: 0.3229 - val_accuracy: 0.8733
# Epoch 199/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.2880 - accuracy: 0.8983 - val_loss: 0.3292 - val_accuracy: 0.8767
# Epoch 200/200
# 117/117 [==============================] - 2s 14ms/step - loss: 0.2874 - accuracy: 0.8981 - val_loss: 0.3253 - val_accuracy: 0.8700

# %%
# loss 값을 plot 해보겠습니다.
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.title('Loss graph without dropout layer') 
plt.ylim(0,1)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# accuracy 값을 plot 해보겠습니다.
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1) 
plt.title('Accuracy graph without dropout layer') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
# Q. dropout layer를 추가해보세요. (dropout 확률은 0.5로 지정해주세요.)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    # 여기에 dropout layer를 추가해보았습니다. 나머지 layer는 위의 실습과 같습니다. 
    # [[YOUR CODE]]
    keras.layers.Dropout(0.5),  # Dropout 레이어 추가 (dropout 확률은 0.5)
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=200, batch_size=512, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/200
# 117/117 [==============================] - 4s 18ms/step - loss: 2.0833 - accuracy: 0.4279 - val_loss: 1.7070 - val_accuracy: 0.5333
# Epoch 2/200
# 117/117 [==============================] - 2s 16ms/step - loss: 1.4812 - accuracy: 0.5489 - val_loss: 1.2410 - val_accuracy: 0.6467
# Epoch 3/200
# 117/117 [==============================] - 2s 16ms/step - loss: 1.1775 - accuracy: 0.6184 - val_loss: 1.0292 - val_accuracy: 0.6950
# Epoch 4/200
# 117/117 [==============================] - 2s 16ms/step - loss: 1.0102 - accuracy: 0.6634 - val_loss: 0.8926 - val_accuracy: 0.7350
# Epoch 5/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.9030 - accuracy: 0.6919 - val_loss: 0.8044 - val_accuracy: 0.7583
# Epoch 6/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.8281 - accuracy: 0.7129 - val_loss: 0.7423 - val_accuracy: 0.7650
# Epoch 7/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.7782 - accuracy: 0.7262 - val_loss: 0.7021 - val_accuracy: 0.7700
# Epoch 8/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.7428 - accuracy: 0.7361 - val_loss: 0.6711 - val_accuracy: 0.7850
# Epoch 9/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.7120 - accuracy: 0.7452 - val_loss: 0.6479 - val_accuracy: 0.7833
# Epoch 10/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.6902 - accuracy: 0.7509 - val_loss: 0.6268 - val_accuracy: 0.7950
# Epoch 11/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.6692 - accuracy: 0.7589 - val_loss: 0.6118 - val_accuracy: 0.7917
# Epoch 12/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.6514 - accuracy: 0.7652 - val_loss: 0.5962 - val_accuracy: 0.7950
# Epoch 13/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.6372 - accuracy: 0.7698 - val_loss: 0.5833 - val_accuracy: 0.7917
# Epoch 14/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.6214 - accuracy: 0.7757 - val_loss: 0.5717 - val_accuracy: 0.7967
# Epoch 15/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.6105 - accuracy: 0.7789 - val_loss: 0.5624 - val_accuracy: 0.7933
# Epoch 16/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5994 - accuracy: 0.7849 - val_loss: 0.5515 - val_accuracy: 0.8017
# Epoch 17/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5864 - accuracy: 0.7899 - val_loss: 0.5456 - val_accuracy: 0.7983
# Epoch 18/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5792 - accuracy: 0.7944 - val_loss: 0.5365 - val_accuracy: 0.8000
# Epoch 19/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.5695 - accuracy: 0.7955 - val_loss: 0.5246 - val_accuracy: 0.8033
# Epoch 20/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5602 - accuracy: 0.8013 - val_loss: 0.5196 - val_accuracy: 0.8083
# Epoch 21/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.5528 - accuracy: 0.8010 - val_loss: 0.5139 - val_accuracy: 0.8083
# Epoch 22/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.5468 - accuracy: 0.8054 - val_loss: 0.5086 - val_accuracy: 0.8133
# Epoch 23/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5396 - accuracy: 0.8068 - val_loss: 0.5032 - val_accuracy: 0.8200
# Epoch 24/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5331 - accuracy: 0.8105 - val_loss: 0.4948 - val_accuracy: 0.8150
# Epoch 25/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5265 - accuracy: 0.8121 - val_loss: 0.4903 - val_accuracy: 0.8217
# Epoch 26/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5224 - accuracy: 0.8138 - val_loss: 0.4865 - val_accuracy: 0.8233
# Epoch 27/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5169 - accuracy: 0.8160 - val_loss: 0.4804 - val_accuracy: 0.8217
# Epoch 28/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5112 - accuracy: 0.8187 - val_loss: 0.4772 - val_accuracy: 0.8183
# Epoch 29/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5050 - accuracy: 0.8209 - val_loss: 0.4723 - val_accuracy: 0.8167
# Epoch 30/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5015 - accuracy: 0.8220 - val_loss: 0.4695 - val_accuracy: 0.8150
# Epoch 31/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4978 - accuracy: 0.8226 - val_loss: 0.4643 - val_accuracy: 0.8267
# Epoch 32/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4938 - accuracy: 0.8238 - val_loss: 0.4593 - val_accuracy: 0.8167
# Epoch 33/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4895 - accuracy: 0.8260 - val_loss: 0.4585 - val_accuracy: 0.8167
# Epoch 34/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4858 - accuracy: 0.8266 - val_loss: 0.4554 - val_accuracy: 0.8200
# Epoch 35/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4805 - accuracy: 0.8300 - val_loss: 0.4545 - val_accuracy: 0.8250
# Epoch 36/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4796 - accuracy: 0.8289 - val_loss: 0.4505 - val_accuracy: 0.8250
# Epoch 37/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4772 - accuracy: 0.8307 - val_loss: 0.4449 - val_accuracy: 0.8267
# Epoch 38/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4731 - accuracy: 0.8341 - val_loss: 0.4433 - val_accuracy: 0.8283
# Epoch 39/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4685 - accuracy: 0.8342 - val_loss: 0.4404 - val_accuracy: 0.8250
# Epoch 40/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.4664 - accuracy: 0.8354 - val_loss: 0.4393 - val_accuracy: 0.8250
# Epoch 41/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4646 - accuracy: 0.8354 - val_loss: 0.4368 - val_accuracy: 0.8267
# Epoch 42/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4592 - accuracy: 0.8388 - val_loss: 0.4336 - val_accuracy: 0.8283
# Epoch 43/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4576 - accuracy: 0.8384 - val_loss: 0.4321 - val_accuracy: 0.8300
# Epoch 44/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4553 - accuracy: 0.8397 - val_loss: 0.4280 - val_accuracy: 0.8383
# Epoch 45/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4536 - accuracy: 0.8402 - val_loss: 0.4256 - val_accuracy: 0.8317
# Epoch 46/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4501 - accuracy: 0.8403 - val_loss: 0.4244 - val_accuracy: 0.8333
# Epoch 47/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4475 - accuracy: 0.8413 - val_loss: 0.4216 - val_accuracy: 0.8350
# Epoch 48/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4473 - accuracy: 0.8414 - val_loss: 0.4202 - val_accuracy: 0.8417
# Epoch 49/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4432 - accuracy: 0.8434 - val_loss: 0.4181 - val_accuracy: 0.8333
# Epoch 50/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4402 - accuracy: 0.8430 - val_loss: 0.4167 - val_accuracy: 0.8333
# Epoch 51/200
# 117/117 [==============================] - 2s 18ms/step - loss: 0.4401 - accuracy: 0.8443 - val_loss: 0.4151 - val_accuracy: 0.8350
# Epoch 52/200
# 117/117 [==============================] - 2s 18ms/step - loss: 0.4374 - accuracy: 0.8461 - val_loss: 0.4121 - val_accuracy: 0.8367
# Epoch 53/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.4345 - accuracy: 0.8465 - val_loss: 0.4097 - val_accuracy: 0.8383
# Epoch 54/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4323 - accuracy: 0.8476 - val_loss: 0.4110 - val_accuracy: 0.8350
# Epoch 55/200
# 117/117 [==============================] - 2s 18ms/step - loss: 0.4316 - accuracy: 0.8471 - val_loss: 0.4069 - val_accuracy: 0.8400
# Epoch 56/200
# 117/117 [==============================] - 2s 19ms/step - loss: 0.4289 - accuracy: 0.8492 - val_loss: 0.4056 - val_accuracy: 0.8400
# Epoch 57/200
# 117/117 [==============================] - 2s 19ms/step - loss: 0.4261 - accuracy: 0.8472 - val_loss: 0.4064 - val_accuracy: 0.8333
# Epoch 58/200
# 117/117 [==============================] - 2s 19ms/step - loss: 0.4267 - accuracy: 0.8490 - val_loss: 0.4045 - val_accuracy: 0.8350
# Epoch 59/200
# 117/117 [==============================] - 2s 18ms/step - loss: 0.4253 - accuracy: 0.8494 - val_loss: 0.4033 - val_accuracy: 0.8383
# Epoch 60/200
# 117/117 [==============================] - 2s 20ms/step - loss: 0.4219 - accuracy: 0.8510 - val_loss: 0.4025 - val_accuracy: 0.8367
# Epoch 61/200
# 117/117 [==============================] - 2s 21ms/step - loss: 0.4211 - accuracy: 0.8514 - val_loss: 0.4006 - val_accuracy: 0.8333
# Epoch 62/200
# 117/117 [==============================] - 2s 20ms/step - loss: 0.4198 - accuracy: 0.8510 - val_loss: 0.3991 - val_accuracy: 0.8350
# Epoch 63/200
# 117/117 [==============================] - 2s 19ms/step - loss: 0.4168 - accuracy: 0.8518 - val_loss: 0.4005 - val_accuracy: 0.8367
# Epoch 64/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4152 - accuracy: 0.8527 - val_loss: 0.3969 - val_accuracy: 0.8400
# Epoch 65/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4171 - accuracy: 0.8519 - val_loss: 0.3965 - val_accuracy: 0.8383
# Epoch 66/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4140 - accuracy: 0.8536 - val_loss: 0.3932 - val_accuracy: 0.8400
# Epoch 67/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4115 - accuracy: 0.8536 - val_loss: 0.3944 - val_accuracy: 0.8450
# Epoch 68/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4099 - accuracy: 0.8548 - val_loss: 0.3937 - val_accuracy: 0.8417
# Epoch 69/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4109 - accuracy: 0.8544 - val_loss: 0.3898 - val_accuracy: 0.8417
# Epoch 70/200
# 117/117 [==============================] - 2s 19ms/step - loss: 0.4079 - accuracy: 0.8557 - val_loss: 0.3914 - val_accuracy: 0.8400
# Epoch 71/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4054 - accuracy: 0.8560 - val_loss: 0.3903 - val_accuracy: 0.8383
# Epoch 72/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4070 - accuracy: 0.8555 - val_loss: 0.3891 - val_accuracy: 0.8383
# Epoch 73/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4042 - accuracy: 0.8571 - val_loss: 0.3869 - val_accuracy: 0.8400
# Epoch 74/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4034 - accuracy: 0.8559 - val_loss: 0.3840 - val_accuracy: 0.8467
# Epoch 75/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.4014 - accuracy: 0.8577 - val_loss: 0.3845 - val_accuracy: 0.8467
# Epoch 76/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4010 - accuracy: 0.8576 - val_loss: 0.3843 - val_accuracy: 0.8400
# Epoch 77/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3980 - accuracy: 0.8585 - val_loss: 0.3838 - val_accuracy: 0.8417
# Epoch 78/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3987 - accuracy: 0.8583 - val_loss: 0.3807 - val_accuracy: 0.8433
# Epoch 79/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3981 - accuracy: 0.8587 - val_loss: 0.3796 - val_accuracy: 0.8433
# Epoch 80/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3944 - accuracy: 0.8608 - val_loss: 0.3791 - val_accuracy: 0.8383
# Epoch 81/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3977 - accuracy: 0.8590 - val_loss: 0.3825 - val_accuracy: 0.8417
# Epoch 82/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3929 - accuracy: 0.8607 - val_loss: 0.3763 - val_accuracy: 0.8483
# Epoch 83/200
# 117/117 [==============================] - 2s 19ms/step - loss: 0.3943 - accuracy: 0.8601 - val_loss: 0.3795 - val_accuracy: 0.8383
# Epoch 84/200
# 117/117 [==============================] - 2s 18ms/step - loss: 0.3911 - accuracy: 0.8619 - val_loss: 0.3746 - val_accuracy: 0.8417
# Epoch 85/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3898 - accuracy: 0.8612 - val_loss: 0.3769 - val_accuracy: 0.8450
# Epoch 86/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3903 - accuracy: 0.8616 - val_loss: 0.3748 - val_accuracy: 0.8433
# Epoch 87/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3891 - accuracy: 0.8621 - val_loss: 0.3723 - val_accuracy: 0.8467
# Epoch 88/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3864 - accuracy: 0.8629 - val_loss: 0.3735 - val_accuracy: 0.8517
# Epoch 89/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3871 - accuracy: 0.8629 - val_loss: 0.3734 - val_accuracy: 0.8450
# Epoch 90/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3875 - accuracy: 0.8628 - val_loss: 0.3748 - val_accuracy: 0.8450
# Epoch 91/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3869 - accuracy: 0.8628 - val_loss: 0.3720 - val_accuracy: 0.8417
# Epoch 92/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3834 - accuracy: 0.8633 - val_loss: 0.3702 - val_accuracy: 0.8400
# Epoch 93/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3833 - accuracy: 0.8639 - val_loss: 0.3721 - val_accuracy: 0.8467
# Epoch 94/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3841 - accuracy: 0.8634 - val_loss: 0.3670 - val_accuracy: 0.8450
# Epoch 95/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3789 - accuracy: 0.8660 - val_loss: 0.3683 - val_accuracy: 0.8433
# Epoch 96/200
# 117/117 [==============================] - 2s 15ms/step - loss: 0.3809 - accuracy: 0.8642 - val_loss: 0.3684 - val_accuracy: 0.8450
# Epoch 97/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3789 - accuracy: 0.8654 - val_loss: 0.3670 - val_accuracy: 0.8500
# Epoch 98/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3801 - accuracy: 0.8654 - val_loss: 0.3674 - val_accuracy: 0.8483
# Epoch 99/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3770 - accuracy: 0.8645 - val_loss: 0.3629 - val_accuracy: 0.8483
# Epoch 100/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3758 - accuracy: 0.8666 - val_loss: 0.3631 - val_accuracy: 0.8517
# Epoch 101/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3760 - accuracy: 0.8657 - val_loss: 0.3646 - val_accuracy: 0.8500
# Epoch 102/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3761 - accuracy: 0.8678 - val_loss: 0.3614 - val_accuracy: 0.8433
# Epoch 103/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3750 - accuracy: 0.8669 - val_loss: 0.3623 - val_accuracy: 0.8500
# Epoch 104/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3730 - accuracy: 0.8659 - val_loss: 0.3645 - val_accuracy: 0.8483
# Epoch 105/200
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3721 - accuracy: 0.8677 - val_loss: 0.3621 - val_accuracy: 0.8550
# Epoch 106/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.3717 - accuracy: 0.8682 - val_loss: 0.3624 - val_accuracy: 0.8450
# Epoch 107/200
# 117/117 [==============================] - 2s 17ms/step - loss: 0.3717 - accuracy: 0.8692 - val_loss: 0.3599 - val_accuracy: 0.8483
# Epoch 108/200
# 117/117 [==============================] - 3s 24ms/step - loss: 0.3712 - accuracy: 0.8684 - val_loss: 0.3561 - val_accuracy: 0.8400
# Epoch 109/200
# 117/117 [==============================] - 3s 28ms/step - loss: 0.3701 - accuracy: 0.8680 - val_loss: 0.3588 - val_accuracy: 0.8467
# Epoch 110/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3707 - accuracy: 0.8684 - val_loss: 0.3591 - val_accuracy: 0.8500
# Epoch 111/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3698 - accuracy: 0.8691 - val_loss: 0.3585 - val_accuracy: 0.8517
# Epoch 112/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3694 - accuracy: 0.8702 - val_loss: 0.3591 - val_accuracy: 0.8550
# Epoch 113/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3687 - accuracy: 0.8685 - val_loss: 0.3547 - val_accuracy: 0.8417
# Epoch 114/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3679 - accuracy: 0.8700 - val_loss: 0.3553 - val_accuracy: 0.8517
# Epoch 115/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3666 - accuracy: 0.8703 - val_loss: 0.3532 - val_accuracy: 0.8533
# Epoch 116/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3672 - accuracy: 0.8690 - val_loss: 0.3556 - val_accuracy: 0.8533
# Epoch 117/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3653 - accuracy: 0.8701 - val_loss: 0.3554 - val_accuracy: 0.8583
# Epoch 118/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3646 - accuracy: 0.8700 - val_loss: 0.3536 - val_accuracy: 0.8467
# Epoch 119/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3632 - accuracy: 0.8702 - val_loss: 0.3541 - val_accuracy: 0.8517
# Epoch 120/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3631 - accuracy: 0.8709 - val_loss: 0.3524 - val_accuracy: 0.8517
# Epoch 121/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3620 - accuracy: 0.8720 - val_loss: 0.3532 - val_accuracy: 0.8550
# Epoch 122/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3619 - accuracy: 0.8723 - val_loss: 0.3544 - val_accuracy: 0.8600
# Epoch 123/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3591 - accuracy: 0.8735 - val_loss: 0.3541 - val_accuracy: 0.8517
# Epoch 124/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3582 - accuracy: 0.8721 - val_loss: 0.3509 - val_accuracy: 0.8567
# Epoch 125/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3605 - accuracy: 0.8726 - val_loss: 0.3522 - val_accuracy: 0.8600
# Epoch 126/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3593 - accuracy: 0.8734 - val_loss: 0.3489 - val_accuracy: 0.8567
# Epoch 127/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3576 - accuracy: 0.8726 - val_loss: 0.3510 - val_accuracy: 0.8583
# Epoch 128/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3560 - accuracy: 0.8745 - val_loss: 0.3486 - val_accuracy: 0.8583
# Epoch 129/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3572 - accuracy: 0.8739 - val_loss: 0.3498 - val_accuracy: 0.8550
# Epoch 130/200
# 117/117 [==============================] - 4s 36ms/step - loss: 0.3556 - accuracy: 0.8740 - val_loss: 0.3467 - val_accuracy: 0.8483
# Epoch 131/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3576 - accuracy: 0.8730 - val_loss: 0.3470 - val_accuracy: 0.8617
# Epoch 132/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3568 - accuracy: 0.8731 - val_loss: 0.3467 - val_accuracy: 0.8550
# Epoch 133/200
# 117/117 [==============================] - 4s 36ms/step - loss: 0.3533 - accuracy: 0.8742 - val_loss: 0.3452 - val_accuracy: 0.8583
# Epoch 134/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3554 - accuracy: 0.8736 - val_loss: 0.3472 - val_accuracy: 0.8600
# Epoch 135/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3528 - accuracy: 0.8743 - val_loss: 0.3476 - val_accuracy: 0.8583
# Epoch 136/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3541 - accuracy: 0.8736 - val_loss: 0.3477 - val_accuracy: 0.8567
# Epoch 137/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3511 - accuracy: 0.8752 - val_loss: 0.3486 - val_accuracy: 0.8550
# Epoch 138/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3520 - accuracy: 0.8746 - val_loss: 0.3450 - val_accuracy: 0.8583
# Epoch 139/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3514 - accuracy: 0.8754 - val_loss: 0.3456 - val_accuracy: 0.8567
# Epoch 140/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3493 - accuracy: 0.8749 - val_loss: 0.3477 - val_accuracy: 0.8600
# Epoch 141/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3492 - accuracy: 0.8763 - val_loss: 0.3442 - val_accuracy: 0.8567
# Epoch 142/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3484 - accuracy: 0.8765 - val_loss: 0.3418 - val_accuracy: 0.8633
# Epoch 143/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3498 - accuracy: 0.8759 - val_loss: 0.3429 - val_accuracy: 0.8600
# Epoch 144/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3475 - accuracy: 0.8765 - val_loss: 0.3412 - val_accuracy: 0.8583
# Epoch 145/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3472 - accuracy: 0.8771 - val_loss: 0.3445 - val_accuracy: 0.8583
# Epoch 146/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3451 - accuracy: 0.8774 - val_loss: 0.3407 - val_accuracy: 0.8617
# Epoch 147/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3469 - accuracy: 0.8772 - val_loss: 0.3405 - val_accuracy: 0.8633
# Epoch 148/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3471 - accuracy: 0.8765 - val_loss: 0.3419 - val_accuracy: 0.8583
# Epoch 149/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3461 - accuracy: 0.8772 - val_loss: 0.3422 - val_accuracy: 0.8633
# Epoch 150/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3457 - accuracy: 0.8778 - val_loss: 0.3391 - val_accuracy: 0.8617
# Epoch 151/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3441 - accuracy: 0.8782 - val_loss: 0.3405 - val_accuracy: 0.8617
# Epoch 152/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3454 - accuracy: 0.8784 - val_loss: 0.3388 - val_accuracy: 0.8700
# Epoch 153/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3430 - accuracy: 0.8787 - val_loss: 0.3393 - val_accuracy: 0.8617
# Epoch 154/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3428 - accuracy: 0.8786 - val_loss: 0.3389 - val_accuracy: 0.8617
# Epoch 155/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3419 - accuracy: 0.8774 - val_loss: 0.3375 - val_accuracy: 0.8617
# Epoch 156/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3432 - accuracy: 0.8778 - val_loss: 0.3349 - val_accuracy: 0.8667
# Epoch 157/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3425 - accuracy: 0.8787 - val_loss: 0.3366 - val_accuracy: 0.8650
# Epoch 158/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3404 - accuracy: 0.8783 - val_loss: 0.3379 - val_accuracy: 0.8650
# Epoch 159/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3398 - accuracy: 0.8797 - val_loss: 0.3399 - val_accuracy: 0.8583
# Epoch 160/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3405 - accuracy: 0.8798 - val_loss: 0.3353 - val_accuracy: 0.8717
# Epoch 161/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3392 - accuracy: 0.8797 - val_loss: 0.3372 - val_accuracy: 0.8667
# Epoch 162/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3421 - accuracy: 0.8799 - val_loss: 0.3391 - val_accuracy: 0.8650
# Epoch 163/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3382 - accuracy: 0.8803 - val_loss: 0.3344 - val_accuracy: 0.8683
# Epoch 164/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3376 - accuracy: 0.8801 - val_loss: 0.3350 - val_accuracy: 0.8667
# Epoch 165/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3379 - accuracy: 0.8794 - val_loss: 0.3336 - val_accuracy: 0.8683
# Epoch 166/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3389 - accuracy: 0.8803 - val_loss: 0.3364 - val_accuracy: 0.8600
# Epoch 167/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3357 - accuracy: 0.8816 - val_loss: 0.3346 - val_accuracy: 0.8717
# Epoch 168/200
# 117/117 [==============================] - 4s 36ms/step - loss: 0.3353 - accuracy: 0.8809 - val_loss: 0.3314 - val_accuracy: 0.8683
# Epoch 169/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3369 - accuracy: 0.8795 - val_loss: 0.3320 - val_accuracy: 0.8633
# Epoch 170/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3368 - accuracy: 0.8821 - val_loss: 0.3306 - val_accuracy: 0.8717
# Epoch 171/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3357 - accuracy: 0.8818 - val_loss: 0.3326 - val_accuracy: 0.8700
# Epoch 172/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3345 - accuracy: 0.8831 - val_loss: 0.3313 - val_accuracy: 0.8683
# Epoch 173/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3350 - accuracy: 0.8828 - val_loss: 0.3332 - val_accuracy: 0.8717
# Epoch 174/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3336 - accuracy: 0.8808 - val_loss: 0.3324 - val_accuracy: 0.8683
# Epoch 175/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3340 - accuracy: 0.8816 - val_loss: 0.3340 - val_accuracy: 0.8617
# Epoch 176/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3329 - accuracy: 0.8819 - val_loss: 0.3306 - val_accuracy: 0.8733
# Epoch 177/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3315 - accuracy: 0.8826 - val_loss: 0.3292 - val_accuracy: 0.8683
# Epoch 178/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3310 - accuracy: 0.8827 - val_loss: 0.3312 - val_accuracy: 0.8650
# Epoch 179/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3314 - accuracy: 0.8824 - val_loss: 0.3292 - val_accuracy: 0.8717
# Epoch 180/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3333 - accuracy: 0.8816 - val_loss: 0.3305 - val_accuracy: 0.8650
# Epoch 181/200
# 117/117 [==============================] - 4s 35ms/step - loss: 0.3320 - accuracy: 0.8820 - val_loss: 0.3290 - val_accuracy: 0.8650
# Epoch 182/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3307 - accuracy: 0.8832 - val_loss: 0.3297 - val_accuracy: 0.8683
# Epoch 183/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3307 - accuracy: 0.8824 - val_loss: 0.3304 - val_accuracy: 0.8700
# Epoch 184/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3286 - accuracy: 0.8833 - val_loss: 0.3287 - val_accuracy: 0.8700
# Epoch 185/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3301 - accuracy: 0.8825 - val_loss: 0.3292 - val_accuracy: 0.8650
# Epoch 186/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3275 - accuracy: 0.8832 - val_loss: 0.3263 - val_accuracy: 0.8733
# Epoch 187/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3273 - accuracy: 0.8834 - val_loss: 0.3242 - val_accuracy: 0.8700
# Epoch 188/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3273 - accuracy: 0.8844 - val_loss: 0.3258 - val_accuracy: 0.8717
# Epoch 189/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3263 - accuracy: 0.8836 - val_loss: 0.3270 - val_accuracy: 0.8650
# Epoch 190/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3265 - accuracy: 0.8840 - val_loss: 0.3266 - val_accuracy: 0.8683
# Epoch 191/200
# 117/117 [==============================] - 4s 34ms/step - loss: 0.3252 - accuracy: 0.8841 - val_loss: 0.3237 - val_accuracy: 0.8683
# Epoch 192/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3246 - accuracy: 0.8843 - val_loss: 0.3250 - val_accuracy: 0.8700
# Epoch 193/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3239 - accuracy: 0.8841 - val_loss: 0.3259 - val_accuracy: 0.8717
# Epoch 194/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3255 - accuracy: 0.8842 - val_loss: 0.3250 - val_accuracy: 0.8717
# Epoch 195/200
# 117/117 [==============================] - 4s 31ms/step - loss: 0.3229 - accuracy: 0.8855 - val_loss: 0.3241 - val_accuracy: 0.8733
# Epoch 196/200
# 117/117 [==============================] - 4s 30ms/step - loss: 0.3235 - accuracy: 0.8846 - val_loss: 0.3266 - val_accuracy: 0.8667
# Epoch 197/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3229 - accuracy: 0.8848 - val_loss: 0.3228 - val_accuracy: 0.8700
# Epoch 198/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3232 - accuracy: 0.8852 - val_loss: 0.3239 - val_accuracy: 0.8750
# Epoch 199/200
# 117/117 [==============================] - 4s 32ms/step - loss: 0.3228 - accuracy: 0.8838 - val_loss: 0.3215 - val_accuracy: 0.8750
# Epoch 200/200
# 117/117 [==============================] - 4s 33ms/step - loss: 0.3245 - accuracy: 0.8847 - val_loss: 0.3242 - val_accuracy: 0.8700

# %%
# Q. loss 값의 그래프를 그려봅시다.
# [[YOUR CODE]]
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.ylim(0,1)
plt.title('Loss graph with dropout layer') 
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# Q. accuracy 값의 그래프를 그려봅시다. 
# [[YOUR CODE]]
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1) 
plt.title('Accuracy graph with dropout layer') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# 좋은 데이터를 가지고 오버피팅을 만드는 환경이 조금 어렵긴 했지만, dropout layer 하나만으로도 오버피팅을 막고, 두 데이터 셋이 정확도도 비슷하게 나옴을 확인하였습니다. 사실 더 복잡한 네트워크나, 더 어려운 데이터의 경우에는 이러한 오버피팅이 더 자주 있는 일이므로, dropout layer를 추가하는 경우

# %% [markdown]
# ## 5-7. Batch Normalization
#
# 논문 제목 : Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift
# 논문 발표 시점 : 2015년
# 논문 링크 : 논문 PDF
# (batch normalization과 internal covariate shift가 연관성이 없다는 반론도 있기 때문에, "이런 이야기도 있구나~" 하고 받아들이시면 됩니다.)
#
# 딥러닝에서 경사 하강법(gradient descent)으로 모델의 가중치를 업데이트할 때, 데이터셋 전체를 본 다음 업데이트하는 'Batch Gradient Descent'와 데이터 하나를 관찰할 때마다 업데이트하는 'Stochastic Gradient Descent' 방법이 있었죠. 이 둘의 절충안이 바로 데이터셋을 여러 개의 mini-batch로 쪼갠 다음 하나의 batch를 처리할 때마다 가중치를 업데이트하는 'Mini-batch Gradient Descent'입니다. 데이터셋을 mini-batch로 쪼개는 방법은 학습 속도와 안정성 모두를 잡았지만, 딥러닝 모델 안에서 데이터가 처리되면서 여러 개의 mini-batch들 사이에 데이터 분포의 차이가 생길 수 있다는 문제가 있었습니다. (이것이 internal covariate shift를 대략적으로 설명한 부분입니다.)
#
# 데이터 분포의 차이가 존재한다면 gradient 값의 차이도 있을 것이고, 같은 learning rate 값을 가지고 있더라도 gradient vanishing이나 gradient explode 문제가 생길 수 있습니다. batch normalization 기법은 각 mini-batch마다 평균과 분산을 계산하여 정규화(normalization)를 수행하고, scale and shift 변환을 적용하여 mini-batch들이 비슷한 데이터 분포를 가지도록 합니다.
#
# 논문에서 설명한 알고리즘을 아래에 적어보도록 하겠습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 실습
# ---
# 아무것도 하지 않은 fully connected layer와 batch normalization layer를 추가한 두 실험을 비교하고자 합니다. 중점적으로 봐야 할 내용은 정확도 비교와 속도의 차이입니다.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = keras.datasets.fashion_mnist
print('=3')
# Out:
# =3

# %% [markdown]
# 이미지 데이터인 fashion mnist 데이터셋을 불러오겠습니다. 총 10개의 클래스로 나누어져 있습니다.

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(train_images, train_labels, test_size=0.3, random_state=101)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history= model.fit(X_train, y_train, epochs=20, batch_size=2048, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 21/21 [==============================] - 2s 55ms/step - loss: 1.2348 - accuracy: 0.6118 - val_loss: 0.7652 - val_accuracy: 0.7269
# Epoch 2/20
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6720 - accuracy: 0.7693 - val_loss: 0.6087 - val_accuracy: 0.7963
# Epoch 3/20
# 21/21 [==============================] - 1s 41ms/step - loss: 0.5674 - accuracy: 0.8092 - val_loss: 0.5448 - val_accuracy: 0.8158
# Epoch 4/20
# 21/21 [==============================] - 1s 41ms/step - loss: 0.5193 - accuracy: 0.8261 - val_loss: 0.5131 - val_accuracy: 0.8248
# Epoch 5/20
# 21/21 [==============================] - 1s 44ms/step - loss: 0.4904 - accuracy: 0.8332 - val_loss: 0.4889 - val_accuracy: 0.8353
# Epoch 6/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4667 - accuracy: 0.8420 - val_loss: 0.4683 - val_accuracy: 0.8407
# Epoch 7/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4485 - accuracy: 0.8490 - val_loss: 0.4532 - val_accuracy: 0.8448
# Epoch 8/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4349 - accuracy: 0.8520 - val_loss: 0.4409 - val_accuracy: 0.8476
# Epoch 9/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4241 - accuracy: 0.8543 - val_loss: 0.4343 - val_accuracy: 0.8506
# Epoch 10/20
# 21/21 [==============================] - 1s 43ms/step - loss: 0.4130 - accuracy: 0.8588 - val_loss: 0.4272 - val_accuracy: 0.8531
# Epoch 11/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4010 - accuracy: 0.8617 - val_loss: 0.4170 - val_accuracy: 0.8538
# Epoch 12/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.3920 - accuracy: 0.8637 - val_loss: 0.4086 - val_accuracy: 0.8580
# Epoch 13/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.3846 - accuracy: 0.8680 - val_loss: 0.4083 - val_accuracy: 0.8566
# Epoch 14/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.3778 - accuracy: 0.8683 - val_loss: 0.4016 - val_accuracy: 0.8598
# Epoch 15/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.3709 - accuracy: 0.8714 - val_loss: 0.3956 - val_accuracy: 0.8612
# Epoch 16/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3651 - accuracy: 0.8731 - val_loss: 0.3874 - val_accuracy: 0.8646
# Epoch 17/20
# 21/21 [==============================] - 1s 43ms/step - loss: 0.3564 - accuracy: 0.8767 - val_loss: 0.3834 - val_accuracy: 0.8644
# Epoch 18/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.3522 - accuracy: 0.8775 - val_loss: 0.3791 - val_accuracy: 0.8656
# Epoch 19/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3467 - accuracy: 0.8796 - val_loss: 0.3762 - val_accuracy: 0.8674
# Epoch 20/20
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3409 - accuracy: 0.8816 - val_loss: 0.3755 - val_accuracy: 0.8679

# %%
# loss 값을 plot 해보겠습니다. 
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.ylim(0,1)
plt.title('Loss graph without batch normalization') 
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# accuracy 값을 plot 해보겠습니다. 
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1)
plt.title('Accuracy graph without batch normalization') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# 아래는 BatchNormalization layer를 추가한 실습입니다.

# %%
# Q. 두 개의 dense layer 사이에 batch normalization layer를 추가하는 코드입니다.

model = keras.Sequential([
    # [[YOUR CODE]]
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    # 여기에 batch normalization layer를 추가해보았습니다. 나머지 layer는 위의 실습과 같습니다.
    keras.layers.BatchNormalization(),
    # [[YOUR CODE]]
    keras.layers.Dense(10, activation='softmax')
])

# [[YOUR CODE]]
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history= model.fit(X_train, y_train, epochs=20, batch_size=2048, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 21/21 [==============================] - 2s 54ms/step - loss: 0.8592 - accuracy: 0.7044 - val_loss: 1.0157 - val_accuracy: 0.7037
# Epoch 2/20
# 21/21 [==============================] - 1s 44ms/step - loss: 0.4989 - accuracy: 0.8301 - val_loss: 0.8442 - val_accuracy: 0.7647
# Epoch 3/20
# 21/21 [==============================] - 1s 45ms/step - loss: 0.4382 - accuracy: 0.8488 - val_loss: 0.7543 - val_accuracy: 0.7983
# Epoch 4/20
# 21/21 [==============================] - 1s 43ms/step - loss: 0.4038 - accuracy: 0.8607 - val_loss: 0.6900 - val_accuracy: 0.8196
# Epoch 5/20
# 21/21 [==============================] - 1s 43ms/step - loss: 0.3800 - accuracy: 0.8696 - val_loss: 0.6331 - val_accuracy: 0.8303
# Epoch 6/20
# 21/21 [==============================] - 1s 45ms/step - loss: 0.3603 - accuracy: 0.8753 - val_loss: 0.5913 - val_accuracy: 0.8362
# Epoch 7/20
# 21/21 [==============================] - 1s 44ms/step - loss: 0.3444 - accuracy: 0.8811 - val_loss: 0.5305 - val_accuracy: 0.8576
# Epoch 8/20
# 21/21 [==============================] - 1s 44ms/step - loss: 0.3290 - accuracy: 0.8862 - val_loss: 0.5124 - val_accuracy: 0.8554
# Epoch 9/20
# 21/21 [==============================] - 1s 44ms/step - loss: 0.3164 - accuracy: 0.8896 - val_loss: 0.4838 - val_accuracy: 0.8578
# Epoch 10/20
# 21/21 [==============================] - 2s 75ms/step - loss: 0.3065 - accuracy: 0.8930 - val_loss: 0.4654 - val_accuracy: 0.8611
# Epoch 11/20
# 21/21 [==============================] - 2s 88ms/step - loss: 0.2955 - accuracy: 0.8967 - val_loss: 0.4481 - val_accuracy: 0.8612
# Epoch 12/20
# 21/21 [==============================] - 2s 82ms/step - loss: 0.2844 - accuracy: 0.9008 - val_loss: 0.4118 - val_accuracy: 0.8702
# Epoch 13/20
# 21/21 [==============================] - 2s 96ms/step - loss: 0.2764 - accuracy: 0.9035 - val_loss: 0.4148 - val_accuracy: 0.8627
# Epoch 14/20
# 21/21 [==============================] - 2s 84ms/step - loss: 0.2675 - accuracy: 0.9053 - val_loss: 0.4037 - val_accuracy: 0.8681
# Epoch 15/20
# 21/21 [==============================] - 2s 89ms/step - loss: 0.2608 - accuracy: 0.9087 - val_loss: 0.3813 - val_accuracy: 0.8760
# Epoch 16/20
# 21/21 [==============================] - 2s 87ms/step - loss: 0.2525 - accuracy: 0.9112 - val_loss: 0.3763 - val_accuracy: 0.8719
# Epoch 17/20
# 21/21 [==============================] - 2s 94ms/step - loss: 0.2470 - accuracy: 0.9124 - val_loss: 0.3620 - val_accuracy: 0.8743
# Epoch 18/20
# 21/21 [==============================] - 2s 94ms/step - loss: 0.2370 - accuracy: 0.9163 - val_loss: 0.3483 - val_accuracy: 0.8814
# Epoch 19/20
# 21/21 [==============================] - 2s 93ms/step - loss: 0.2294 - accuracy: 0.9193 - val_loss: 0.3477 - val_accuracy: 0.8805
# Epoch 20/20
# 21/21 [==============================] - 2s 93ms/step - loss: 0.2262 - accuracy: 0.9198 - val_loss: 0.3487 - val_accuracy: 0.8777

# %%
# loss 값을 plot 해보겠습니다. 
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss")
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss")
plt.legend(loc='upper right')
plt.grid()
plt.ylim(0,1)
plt.title('Loss graph with batch normalization') 
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
# accuracy 값을 plot 해보겠습니다. 
y_vacc = history.history['val_accuracy']
y_acc = history.history['accuracy']
x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vacc, marker='.', c='red', label="Validation-set accuracy")
plt.plot(x_len, y_acc, marker='.', c='blue', label="Train-set accuracy")
plt.legend(loc='lower right')
plt.grid()
plt.ylim(0.5,1) 
plt.title('Accurcy graph with batch normalization') 
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# 기존의 fully connected layer도 낮지 않은 결과를 가져오지만, batch normalization을 추가하니 좀 더 빠르게 정확도 상승이 있음을 확인할 수 있습니다. 또한 loss 함수의 감소도 더 빨라짐을 확인할 수 있었습니다. 즉 batch normalization으로 인해 데이터 분포가 정규화되면서 좀 더 고른 분포를 가지기도 하며, 모델과 함께 학습되는γ,β 파라미터로 데이터 분포를 적절하게 변환함으로써 보다 안정적인 학습이 가능해집니다.

# %% [markdown]
# Q. L1 regularization과 L2 regularization의 공통점과 차이점은 무엇이었나요?
#
# 공통점:
# - L1과 L2 regularization 는 모두 모델의 복잡도를 줄여 과적합을 방지하는 방법입니다.
# - 비용 함수에 정규화 항을 추가하여 가중치의 크기를 줄이는 것을 목표로 합니다.
#
# 차이점:
# - L1 regularization(Lasso)는 가중치의 절대값의 합을 사용해 일부 가중치를 0으로 만들어 특성 선택 효과가 있습니다.
# - L2 regularization(Ridge)는 가중치의 제곱합을 사용해 모든 가중치를 작게 하여 모든 특성을 조금씩 사용하게 만듭니다.
